# %%
from datetime import datetime

print("----------------------------------------------------------------------------")
print(f"Last modified: {datetime.now().strftime("%d %B %Y, %H:%M")}")
print("----------------------------------------------------------------------------")
# Out:
# ----------------------------------------------------------------------------
# Last modified: 13 September 2025, 20:10
# ----------------------------------------------------------------------------

# %% [markdown]
# # DF ggH Categories (with Global and 0/1-Jet Selection Cuts)
#
# This notebook extends `kinematic_plots.ipynb` by including the **selection cuts** defined in the `global_selection` function, as well as the **0-jet and 1-jet categories** from the `select_0jet_category` function.
#
# In short, it combines all content from `kinematic_plots.ipynb` with the added global and jet-category selections.

# %% [markdown]
# ### Verifying the Notebook Environment
#
# Before starting the analysis, it’s a good idea to make sure our notebook is running smoothly. We do this by executing a simple test cell in Jupyter to confirm everything is working as expected.

# %%
print("Higgs")
# Out:
# Higgs

# %% [markdown]
# ### Setting the Working Directory
#
# To make our workflow easier, we set the working directory to the folder containing the input ROOT files. This way, we can reference file paths relative to this directory, avoiding long and error-prone absolute paths.

# %%
import os 
# Check the current directory
print("Current directory:", os.getcwd())

# Change to the folder containing NanoAOD ROOT files
os.chdir("C:\MAIN\HSF-India\MC_samples_final")

# Confirm the change
print("\nNew working directory:", os.getcwd())

for file in os.listdir():
    if file.endswith(".root"):
        print(f'{file}')
# Out:
# Current directory: c:\MAIN\HSF-India\H-to-WW-NanoAOD-analysis\notebooks
#
# New working directory: C:\MAIN\HSF-India\MC_samples_final
# Diboson.root
# DY.root
# Higgs.root
# Single_top.root
# TTBar.root
# Wjets.root
# <>:6: SyntaxWarning: invalid escape sequence '\M'
# <>:6: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\Anuj\AppData\Local\Temp\ipykernel_22192\1311247291.py:6: SyntaxWarning: invalid escape sequence '\M'
#   os.chdir("C:\MAIN\HSF-India\MC_samples_final")

# %% [markdown]
# ### Python Setup
#
# First, import the required libraries for handling NanoAOD data and analysis:
#
# - **`uproot`**: to open and read ROOT files
# - **`awkward`**: to work with jagged arrays (event-based data)
# - **`numpy`**: for numerical computations
# - **`matplotlib`**: for plotting and visualization
# - **`vector`**: to handle four-vectors (momenta, invariant mass, $\Delta R$, etc.)
# - **`hist`**: to create histograms in a high-energy physics style
#
# Finally, register `vector` with `awkward` to enable four-vector operations directly on event data.

# %%
import uproot
import awkward as ak
import numpy as np
import matplotlib.pyplot as plt
import vector
from hist import Hist

# Register vector support for awkward arrays
vector.register_awkward()

# %% [markdown]
# ### Defining Input Files
#
# We now specify the input ROOT files as a dictionary. Each key is a dataset label, and each value is the corresponding file:
#
# - **Signal**: `higgs.root` → Higgs boson production via gluon–gluon fusion ($gg \to H$), followed by the decay $H \to WW$
# - **Drell–Yan ($\tau^+\tau^-$)**: `DY.root` → background from $q\bar{q} \to Z/\gamma^* \to \tau^+\tau^-$
# - **Top quark pair ($t\bar{t}$)**: `ttbar.root` → background from top–antitop production
# - **Diboson**: `Diboson.root` → background from $WW$, $WZ$, and $ZZ$ processes
# - **Single Top**: `SingleTop.root` → background from single top quark production
# - **$W$ + jets (fakes)**: `Wjetstolnu.root` → background from $W \to \ell\nu$ with additional jets, can mimic signal-like events

# %%
files = {
    "signal": "Higgs.root",   # Signal
    "DY to Tau_Tau": "DY.root",       # Drell-Yan background
    "Top antitop": "TTBar.root",    # Top quark pair background
    "Diboson": "Diboson.root",       # Diboson background
    "Single Top": "Single_top.root",    # Single top background
    "Wjets": "Wjets.root"      # Fakes background
   
}

# %% [markdown]
# ### Defining Plot Colors
#
# For better visualization, assign a distinct color to each dataset:
#
# - **Signal** ($gg \to H \to WW$): red
# - **Drell–Yan ($\tau^+\tau^-$)**: blue
# - **Top quark pair ($t\bar{t}$)**: green
# - **Diboson ($WW$, $WZ$, $ZZ$)**: purple
# - **Single Top**: brown
# - **$W$ + jets (fakes)**: cyan

# %%
colors = {
    "signal": "red",       # Signal
    "DY to Tau_Tau": "blue",       # Drell-Yan background
    "Top antitop": "green",      # Top quark pair background
    "Diboson": "yellow",     # Diboson background
    "Single Top": "brown",    # single top background
     "Wjets": "pink"        # fakes background
}

# %% [markdown]
# ### Checking Available Datasets
#
# Before moving forward, it’s a good idea to print the list of dataset labels. This helps us confirm that the input dictionary has been set up correctly and that all expected datasets are available for analysis.

# %%
print("Files to process:")
for key, file in files.items():
    print(f"{file}")
# Out:
# Files to process:
# Higgs.root
# DY.root
# TTBar.root
# Diboson.root
# Single_top.root
# Wjets.root

# %%
f = uproot.open(files["signal"])

print("\nKeys in the ROOT file:")
for key in f.keys():
    print(key)

electron_branches = [branch for branch in f['Events'].keys() if "Electron" in branch]
muon_branches = [branch for branch in f['Events'].keys() if "Muon" in branch]
MET_branches = [branch for branch in f['Events'].keys() if "MET" in branch]
Jet_branches = [branch for branch in f['Events'].keys() if "Jet" in branch]

# for branch in electron_branches:
#     print(f"-{branch}")

# for branch in muon_branches:
#     print(f"-{branch}")

# for branch in MET_branches:
#     print(f"-{branch}")

# for branch in Jet_branches:
#     print(f"-{branch}")
# Out:
# Keys in the ROOT file:
# Events;1

# %% [markdown]
# ### Loading Events
#
# Define a function `load_events` to read ROOT files with **uproot** and extract key branches for electrons, muons, and missing transverse energy (MET).

# %%
def load_events(filename, batch_size=100000):
    """Load events from a ROOT file in batches"""
    print(f"\nProcessing: {filename}")
    
    columns = [
        # Electrons
        "Electron_pt", "Electron_eta", "Electron_phi", "Electron_mass", 
        "Electron_mvaFall17V2Iso_WP90", "Electron_charge",
        
        # Muons
        "Muon_pt", "Muon_eta", "Muon_phi", "Muon_mass", 
        "Muon_tightId", "Muon_charge", "Muon_pfRelIso04_all",
        
        # MET
        "MET_pt", "MET_phi",
        
        # Jets
        "Jet_pt", "Jet_eta", "Jet_phi", "Jet_mass",
        "Jet_btagDeepFlavB", "nJet", "Jet_jetId", "Jet_puId",
    ]
    
    with uproot.open(filename) as f:
        tree = f['Events']
        total_entries = tree.num_entries
        print(f"Total events: {total_entries}")
        
        # Iterate over the file in batches
        for batch_num, arrays in enumerate(tree.iterate(
            columns, 
            step_size=batch_size, 
            library="ak"
        )):
            print(f"Processing batch {batch_num + 1} ({len(arrays)} events)")
            yield arrays

# %% [markdown]
# ### Selecting Tight Leptons
#
# This function applies identification and isolation cuts to electrons and muons:
#
# 1. **Electron selection**:
#    - Require `mvaFall17V2Iso_WP90 == 1`
#
# 2. **Muon selection**:
#    - Require `tightId == 1`
#    - Relative isolation `pfRelIso04_all < 0.15`
#
# 3. **Create structured arrays** for selected leptons containing:
#    - Transverse momentum ($p_T$)
#    - Pseudorapidity ($\eta$)
#    - Azimuthal angle ($\phi$)
#    - Mass
#    - Charge
#    - Flavor code (11 for electrons, 13 for muons)
#
# 4. **Combine electrons and muons** into a single `tight_leptons` collection.
#
# The function returns the combined leptons and the individual selection masks for electrons and muons.

# %%
def select_tight_leptons(arrays):
    """Apply tight ID and isolation cuts to leptons"""
    # Define selection masks
    tight_electron_mask = arrays.Electron_mvaFall17V2Iso_WP90 == 1
    tight_muon_mask = (arrays.Muon_tightId == 1) & (arrays.Muon_pfRelIso04_all < 0.15)
    
    # Create structured arrays for selected leptons
    tight_electrons = ak.zip({
        "pt": arrays.Electron_pt[tight_electron_mask],
        "eta": arrays.Electron_eta[tight_electron_mask],
        "phi": arrays.Electron_phi[tight_electron_mask],
        "mass": arrays.Electron_mass[tight_electron_mask],
        "charge": arrays.Electron_charge[tight_electron_mask],
        "flavor": ak.ones_like(arrays.Electron_pt[tight_electron_mask]) * 11
    })
    
    tight_muons = ak.zip({
        "pt": arrays.Muon_pt[tight_muon_mask],
        "eta": arrays.Muon_eta[tight_muon_mask],
        "phi": arrays.Muon_phi[tight_muon_mask],
        "mass": arrays.Muon_mass[tight_muon_mask],
        "charge": arrays.Muon_charge[tight_muon_mask],
        "flavor": ak.ones_like(arrays.Muon_pt[tight_muon_mask]) * 13
    })
    
    # Combine into single collection
    tight_leptons = ak.concatenate([tight_electrons, tight_muons], axis=1)
    
    return tight_leptons, tight_electron_mask, tight_muon_mask

# %% [markdown]
# ### Selecting $e\mu$ Events
#
# This function selects events containing exactly one electron and one muon:
#
# 1. **Sort leptons** by transverse momentum ($p_T$) in descending order.
# 2. **Require at least two leptons** per event.
# 3. **Identify leading and subleading leptons** based on $p_T$.
# 4. **Apply selection criteria**:
#    - Exactly one electron and one muon per event
#    - Opposite charges for the two leptons
#    - Leading lepton $p_T > 25$ GeV, subleading lepton $p_T > 15$ GeV (configurable)
# 5. **Cutflow tracking**:
#    - `events_2lep`: events with at least two leptons
#    - `events_1e1mu`: events with exactly one electron and one muon
#    - `events_opposite_charge`: events passing the opposite-charge requirement
#    - `events_final`: events passing all selection criteria
#
# Returns the leading and subleading leptons passing all cuts, along with the cutflow dictionary.

# %%
def select_e_mu_events(tight_leptons, met_arrays, leading_pt_cut=25, subleading_pt_cut=15):
    """Select events with exactly 1 electron and 1 muon"""
    
    # Sort by pT
    sorted_leptons = tight_leptons[ak.argsort(tight_leptons.pt, ascending=False)]
    
    # Require at least 2 leptons
    mask_2lep = ak.num(sorted_leptons) >= 2
    events_2lep = sorted_leptons[mask_2lep]
    met_2lep = met_arrays[mask_2lep] 
    
    if len(events_2lep) == 0:
        return None, None, {}, None
    
    # Get leading and subleading
    leading = events_2lep[:, 0]
    subleading = events_2lep[:, 1]
    
    # Selection criteria
    mask_1e1mu = ((leading.flavor == 11) & (subleading.flavor == 13)) | \
                 ((leading.flavor == 13) & (subleading.flavor == 11))
    mask_opposite_charge = leading.charge * subleading.charge < 0
    mask_pt = (leading.pt > leading_pt_cut) & (subleading.pt > subleading_pt_cut)
    
    # Final selection
    final_mask = mask_1e1mu & mask_opposite_charge & mask_pt
    
    # Store cutflow information
    cutflow = {
        'events_2lep': len(leading),
        'events_1e1mu': ak.sum(mask_1e1mu),
        'events_opposite_charge': ak.sum(mask_1e1mu & mask_opposite_charge),
        'events_final': ak.sum(final_mask)
    }
    
    return leading[final_mask], subleading[final_mask], cutflow, met_2lep[final_mask]

# %% [markdown]
# ### Calculating the Invariant Mass of the eμ System
#
# The invariant mass of the electron–muon pair is a key kinematic variable that helps characterize the event. It is defined as:
#
# $$
# m_{e\mu}^2 = (p_e + p_\mu)^2
# $$
#
# where $p_e$ and $p_\mu$ are the four-momenta of the electron and muon.
#
# To calculate this in practice, we use the `vector` library:
#
# 1. Build four-vectors for each lepton from their $(p_T, \eta, \phi, m)$ components.
# 2. Sum the electron and muon four-vectors to form the eμ system.
# 3. Extract the invariant mass from this combined four-vector.
#
# This variable is particularly useful for distinguishing signal events from backgrounds based on the mass distribution of the lepton pair.

# %%
def cal_inv_mass(leading, subleading):
    """Calculate e-mu invariant mass using vector library"""

    # Take the leading electron and muon
    # electron = electrons[:, 0]
    # muon = muons[:, 0]
    
    # Create 4-vectors
    lepton_1 = vector.array({
        "pt": leading.pt,
        "eta": leading.eta,
        "phi": leading.phi,
        "mass": leading.mass
    })
    
    lepton_2 = vector.array({
        "pt": subleading.pt,
        "eta": subleading.eta,
        "phi": subleading.phi,
        "mass": subleading.mass
    })
    
    # Add 4-vectors and get invariant mass
    dilepton = lepton_1 + lepton_2
    return dilepton.mass

# %% [markdown]
# ### Calculating the Azimuthal Angle Separation $\Delta \phi_{\ell\ell}$
#
# The azimuthal angle separation between the electron and muon is defined as:
#
# $$
# \Delta\phi_{\ell\ell} = \phi_e - \phi_\mu \quad \in [-\pi, \pi]
# $$
#
# After calculating, we take the absolute value, ensuring it lies within the interval \([-π, π]\).
#
# **Physics motivation:**
# - In $H \to WW \to e\nu\mu\nu$, the spin–0 nature of the Higgs boson tends to produce leptons that are **closer in angle**, resulting in smaller $\Delta\phi_{\ell\ell}$.
# - Background processes, such as Drell–Yan or $t\bar{t}$, often lead to larger $\Delta\phi_{\ell\ell}$ values.
# - This makes $\Delta\phi_{\ell\ell}$ a **powerful discriminating variable** between signal and background.

# %%
def cal_dphill(leading, subleading):
    """Calculate delta phi between electron and muon"""
    # electron = electrons[:, 0]
    # muon = muons[:, 0]
    
    # Calculate delta phi
    dphi = leading.phi - subleading.phi
    
    # Wrap to [-pi, pi]
    dphi = np.where(dphi > np.pi, dphi - 2*np.pi, dphi)
    dphi = np.where(dphi < -np.pi, dphi + 2*np.pi, dphi)
    
    return np.abs(dphi)

# %% [markdown]
# ### Calculating the Dilepton Transverse Momentum ($p_{T}^{\ell\ell}$)
#
# The dilepton transverse momentum is defined as the magnitude of the transverse momentum of the electron–muon system:
#
# $$
# p_{T}^{\ell\ell} = \left| \vec{p}_{T}^{\,e} + \vec{p}_{T}^{\,\mu} \right|
# $$
#
# **Why this matters:**
# - Signal events from $H \to WW$ often exhibit a **different $p_{T}^{\ell\ell}$ distribution** compared to backgrounds like Drell–Yan or $t\bar{t}$.
# - It provides insight into the **Higgs boson recoil**, either against jets or missing transverse energy, helping us better characterize the event.

# %%
def cal_ptll(leading, subleading):
    """Calculate dilepton transverse momentum"""

    # Take the leading electron and muon
    # electron = electrons[:, 0]
    # muon = muons[:, 0]
    
    # Create 4-vectors
    lep1_vec = vector.array({
        "pt": leading.pt,
        "eta": leading.eta,
        "phi": leading.phi,
        "mass": leading.mass
    })
    
    lep2_vec = vector.array({
        "pt": subleading.pt,
        "eta": subleading.eta,
        "phi": subleading.phi,
        "mass": subleading.mass
    })
    
    # Add 4-vectors and get pt
    dilepton = lep1_vec + lep2_vec
    return dilepton.pt

# %% [markdown]
# ### Transverse mass of Higgs   **(New)**

# %%
def calculate_mt_higgs(leading, subleading, met):
    """Calculate transverse mass of the Higgs candidate
    
    mT^H = sqrt(2 * pT_ll * MET * (1 - cos(dphi)))
    where dphi is between dilepton system and MET
    """
    # Create dilepton 4-vectors
    lep1 = vector.array({
        "pt": leading.pt,
        "eta": leading.eta,
        "phi": leading.phi,
        "mass": leading.mass
    })
    
    lep2 = vector.array({
        "pt": subleading.pt,
        "eta": subleading.eta,
        "phi": subleading.phi,
        "mass": subleading.mass
    })
    
    # Dilepton system
    dilepton = lep1 + lep2
    
    # Calculate dphi between dilepton and MET
    dphi = dilepton.phi - met.phi
    dphi = np.where(dphi > np.pi, dphi - 2*np.pi, dphi)
    dphi = np.where(dphi < -np.pi, dphi + 2*np.pi, dphi)
    
    # Calculate transverse mass
    mt_higgs = np.sqrt(2 * dilepton.pt * met.pt * (1 - np.cos(dphi)))
    
    return mt_higgs

# %% [markdown]
# ### Transverse mass between subleading lepton and MET  **(New)**

# %%
def calculate_mt_l2_met(subleading, met):
    """Calculate transverse mass between subleading lepton and MET
    
    mT(l2, MET) = sqrt(2 * pT_l2 * MET * (1 - cos(dphi)))
    """
    # Calculate dphi between subleading lepton and MET
    dphi = subleading.phi - met.phi
    dphi = np.where(dphi > np.pi, dphi - 2*np.pi, dphi)
    dphi = np.where(dphi < -np.pi, dphi + 2*np.pi, dphi)
    
    # Calculate transverse mass
    mt_l2_met = np.sqrt(2 * subleading.pt * met.pt * (1 - np.cos(dphi)))
    
    return mt_l2_met

# %% [markdown]
# ### Global Selection  **(New)**

# %%
def global_selection(leading, subleading, met):
    """Apply global H→WW selection cuts and return selected events with kinematics"""
    
    # Compute event-level observables
    masses = cal_inv_mass(leading, subleading)
    ptlls = cal_ptll(leading, subleading)
    dphis = cal_dphill(leading, subleading)  
    
    # Define global cuts
    mask_pt = (leading.pt > 25) & (subleading.pt > 15)  
    mask_mll = masses > 12                              
    mask_met = met.pt > 20                              
    mask_ptll = ptlls > 30                              
    
    # Combine all masks
    global_mask = mask_pt & mask_mll & mask_met & mask_ptll
    
    
    return {
        'leading': leading[global_mask],
        'subleading': subleading[global_mask],
        'met': met[global_mask],  
        'mll': masses[global_mask],
        'ptll': ptlls[global_mask],
        'dphill': dphis[global_mask],
        'mask': global_mask
    }

# %% [markdown]
# ### Select 0-jet and 1-jet category   **(New)**

# %%
def select_0jet_category(selected_events, arrays):
    """Apply 0-jet ggH category selection
       (also showing commented 1-jet cuts for reference)
    
    0-jet Requirements:
    - pT2 (subleading lepton) >= 20 GeV
    - mT^H > 60 GeV
    - mT(l2, pT^miss) > 30 GeV
    - No jet with pT > 30 GeV
    - No b-tagged jet with pT > 20 GeV
    """
    
    # Extract variables from selected events
    leading = selected_events['leading']
    subleading = selected_events['subleading']
    met = selected_events['met']
    global_mask = selected_events['mask']
    
    # Calculate transverse masses
    mt_higgs = calculate_mt_higgs(leading, subleading, met)
    mt_l2_met = calculate_mt_l2_met(subleading, met)
    
    # Apply 0-jet specific cuts
    mask_pt2 = subleading.pt >= 20
    
    
    mask_mth = mt_higgs > 60
    
    
    mask_mt_l2 = mt_l2_met > 30
    
    
    # Jet veto: No jet with pT > 30 GeV
    good_jets_mask = (arrays.Jet_jetId >= 2) 
    
    jet_pt_30_mask = (arrays.Jet_pt > 30) & good_jets_mask
    n_jets_30 = ak.sum(jet_pt_30_mask, axis=1)
    
    n_jets_30_selected = n_jets_30[global_mask]
    # 0-jet:
    mask_jet_veto = n_jets_30_selected == 0

    # 1-jet: 
    # mask_1jet = (n_jets_30_selected == 1)  # exactly 1 jet with pT > 30 GeV
    
    # B-jet veto: No b-tagged jet with pT > 20 GeV
    bjet_mask = (arrays.Jet_pt > 20) & good_jets_mask & (arrays.Jet_btagDeepFlavB > 0.3)
    n_bjets_20 = ak.sum(bjet_mask, axis=1)
    n_bjets_20_selected = n_bjets_20[global_mask]
    mask_bjet_veto = n_bjets_20_selected == 0
    # 1-jet: mask_bjet_veto_1jet = n_bjets_20_selected == 0 
    
    # Combine all masks
    mask_0jet = mask_pt2 & mask_mth & mask_mt_l2 & mask_jet_veto & mask_bjet_veto
    # 1-jet: mask_1jet_combined = mask_pt2_1jet & mask_mth_1jet & mask_mt_l2_1jet & mask_1jet & mask_bjet_veto_1jet
    
    # Cutflow summary
    cutflow_0jet = {
        'after_global': len(mask_pt2),
        'pt2>=20': ak.sum(mask_pt2),
        'mT_H>60': ak.sum(mask_pt2 & mask_mth),
        'mT_l2_met>30': ak.sum(mask_pt2 & mask_mth & mask_mt_l2),
        'jet_veto': ak.sum(mask_pt2 & mask_mth & mask_mt_l2 & mask_jet_veto),
        'bjet_veto': ak.sum(mask_0jet),
        'final_0jet': ak.sum(mask_0jet)
    }
    
    
    return {
        'leading': leading[mask_0jet],
        'subleading': subleading[mask_0jet],
        'met': met[mask_0jet],
        'mll': selected_events['mll'][mask_0jet],
        'ptll': selected_events['ptll'][mask_0jet],
        'dphill': selected_events['dphill'][mask_0jet],
        'mt_higgs': mt_higgs[mask_0jet],
        'mt_l2_met': mt_l2_met[mask_0jet],
        'n_jets_30': n_jets_30_selected[mask_0jet],
        'mask_0jet': mask_0jet,
        'cutflow': cutflow_0jet
    }

# %% [markdown]
# ### Initializing Containers
#
# To keep the analysis organized, we set up three dictionaries:
#
# - **`hist_data`** → Stores histogram values for each dataset.
# - **`selected_leptons`** → Tracks the electrons and muons selected for each dataset.
# - **`event_variables`** → Holds derived kinematic quantities such as:
#   - Invariant mass ($m_{e\mu}$)
#   - Dilepton transverse momentum ($p_{T}^{\ell\ell}$)
#   - Azimuthal separation ($\Delta \phi_{\ell\ell}$)
#
# This modular structure makes it straightforward to loop over samples and fill histograms consistently, keeping the workflow clean and organized.

# %%
hist_data = {}
selected_leptons = {}
event_variables = {}

# %% [markdown]
# ### Defining Histogram Bins
#
# Next, we define the bin edges for the key observables:
#
# - **Invariant mass ($m_{e\mu}$):** 0 - 200 GeV
# - **Missing transverse energy (MET):** 0 - 200 GeV
# - **Azimuthal separation ($\Delta \phi_{\ell\ell}$):** 0 - π
# - **Dilepton transverse momentum ($p_T^{\ell\ell}$):** 0 - 200 GeV
#
# Each observable is divided into **25 bins**.
#
# These ranges are chosen to cover the bulk of expected signal and background events while excluding extreme tails, which are sparsely populated and contribute little statistical information.

# %%
mass_bins = np.linspace(10, 200, 25)     # Invariant mass bins from 0 to 200 GeV
met_bins = np.linspace(0, 200, 25)      # MET bins from 0 to 200 GeV
dphi_bins = np.linspace(0, np.pi, 25)   # Delta phi bins from 0 to π    
ptll_bins = np.linspace(0, 200, 25)     # Dilepton pt bins from 0 to 200 GeV

# %% [markdown]
# ### Event Loop and Variable Calculation
#
# Iterate over all input files to process events and compute key physics variables:
#
# 1. **Load events** from each ROOT file using `load_events`.
# 2. **Select tight leptons** with `select_tight_leptons`.
# 3. **Apply $e\mu$ selection** using `select_e_mu_events` to get leading and subleading leptons and track cutflow.
# 4. **Compute event-level variables** for selected events:
#    - **Invariant mass** of the dilepton system (`calculate_invariant_mass`)
#    - **Azimuthal angle difference** between leptons (`calculate_dphill`)
#    - **Transverse momentum of dilepton system** (`calculate_ptll`)
#    - **MET** from the event (`arrays.MET_pt` and `arrays.MET_phi`)
# 5. **Store results** in a dictionary `event_variables` keyed by dataset label.
# 6. **Print cutflow summary** for the number of events passing all selections.
# 7. **Handle errors** for any problematic file.

# %%
import gc

for label, fname in files.items():
    print(f'Processing file: {fname} ({label})')
    
    # Initialize collectors
    collected_events = {
        "mass": [], "met": [], "dphi": [], "ptll": [],
        "leading": [], "subleading": [], "mt_higgs": [], "mt_l2_met": []
    }
    total_cutflow = {"events_final": 0, "global_selection": 0, "final_0jet": 0}
    
    try:
        # Process file in batches
        for arrays in load_events(fname, batch_size=100000):
            
            tight_leptons, e_mask, mu_mask = select_tight_leptons(arrays)
            
            met = ak.zip({
                "pt": arrays.MET_pt,
                "phi": arrays.MET_phi,
            })
            
            leading, subleading, cutflow, met_selected = select_e_mu_events(tight_leptons, met)
            
            if leading is not None and len(leading) > 0:
                selected = global_selection(leading, subleading, met_selected)
                selected_0jet = select_0jet_category(selected, arrays)
                
                # Collect events from this batch
                if len(selected_0jet['mll']) > 0:
                    collected_events["mass"].append(selected_0jet['mll'])
                    collected_events["met"].append(selected_0jet['met'].pt)
                    collected_events["dphi"].append(selected_0jet['dphill'])
                    collected_events["ptll"].append(selected_0jet['ptll'])
                    collected_events["leading"].append(selected_0jet['leading'])
                    collected_events["subleading"].append(selected_0jet['subleading'])
                    collected_events["mt_higgs"].append(selected_0jet['mt_higgs'])
                    collected_events["mt_l2_met"].append(selected_0jet['mt_l2_met'])
                
                # Update counters
                total_cutflow["events_final"] += cutflow["events_final"]
                total_cutflow["global_selection"] += len(selected["leading"])
                total_cutflow["final_0jet"] += selected_0jet["cutflow"]["final_0jet"]
            
            # Clear batch memory
            del arrays
            gc.collect()
        
        # Concatenate all batches
        if collected_events["mass"]:  # Check if any events passed
            event_variables[label] = {
                key: ak.concatenate(values) 
                for key, values in collected_events.items()
            }
            
            print(f'e-mu events after channel selection: {total_cutflow["events_final"]}')
            print(f'Events after global selection: {total_cutflow["global_selection"]}')
            print(f'Events in 0-jet category: {total_cutflow["final_0jet"]}\n')
        
    except Exception as e:
        print(f"Error processing {fname}: {e}")
        import traceback
        traceback.print_exc()
# Out:
# Processing file: Higgs.root (signal)
#
# Processing: Higgs.root
# Total events: 2838995
# Processing batch 1 (100000 events)
# Processing batch 2 (100000 events)
# Processing batch 3 (100000 events)
# Processing batch 4 (100000 events)
# Processing batch 5 (100000 events)
# Processing batch 6 (100000 events)
# Processing batch 7 (100000 events)
# Processing batch 8 (100000 events)
# Processing batch 9 (100000 events)
# Processing batch 10 (100000 events)
# Processing batch 11 (100000 events)
# Processing batch 12 (100000 events)
# Processing batch 13 (100000 events)
# Processing batch 14 (100000 events)
# Processing batch 15 (100000 events)
# Processing batch 16 (100000 events)
# Processing batch 17 (100000 events)
# Processing batch 18 (100000 events)
# Processing batch 19 (100000 events)
# Processing batch 20 (100000 events)
# Processing batch 21 (100000 events)
# Processing batch 22 (100000 events)
# Processing batch 23 (100000 events)
# Processing batch 24 (100000 events)
# Processing batch 25 (100000 events)
# Processing batch 26 (100000 events)
# Processing batch 27 (100000 events)
# Processing batch 28 (100000 events)
# Processing batch 29 (38995 events)
# e-mu events after channel selection: 187533
# Events after global selection: 138083
# Events in 0-jet category: 16029
#
# Processing file: DY.root (DY to Tau_Tau)
#
# Processing: DY.root
# Total events: 81632177
# Processing batch 1 (100000 events)
# Processing batch 2 (100000 events)
# Processing batch 3 (100000 events)
# Processing batch 4 (100000 events)
# Processing batch 5 (100000 events)
# Processing batch 6 (100000 events)
# Processing batch 7 (100000 events)
# Processing batch 8 (100000 events)
# Processing batch 9 (100000 events)
# Processing batch 10 (100000 events)
# Processing batch 11 (100000 events)
# Processing batch 12 (100000 events)
# Processing batch 13 (100000 events)
# Processing batch 14 (100000 events)
# Processing batch 15 (100000 events)
# Processing batch 16 (100000 events)
# Processing batch 17 (100000 events)
# Processing batch 18 (100000 events)
# Processing batch 19 (100000 events)
# Processing batch 20 (100000 events)
# Processing batch 21 (100000 events)
# Processing batch 22 (100000 events)
# Processing batch 23 (100000 events)
# Processing batch 24 (100000 events)
# Processing batch 25 (100000 events)
# Processing batch 26 (100000 events)
# Processing batch 27 (100000 events)
# Processing batch 28 (100000 events)
# Processing batch 29 (100000 events)
# Processing batch 30 (100000 events)
# Processing batch 31 (100000 events)
# Processing batch 32 (100000 events)
# Processing batch 33 (100000 events)
# Processing batch 34 (100000 events)
# Processing batch 35 (100000 events)
# Processing batch 36 (100000 events)
# Processing batch 37 (100000 events)
# Processing batch 38 (100000 events)
# Processing batch 39 (100000 events)
# Processing batch 40 (100000 events)
# Processing batch 41 (100000 events)
# Processing batch 42 (100000 events)
# Processing batch 43 (100000 events)
# Processing batch 44 (100000 events)
# Processing batch 45 (100000 events)
# Processing batch 46 (100000 events)
# Processing batch 47 (100000 events)
# Processing batch 48 (100000 events)
# Processing batch 49 (100000 events)
# Processing batch 50 (100000 events)
# Processing batch 51 (100000 events)
# Processing batch 52 (100000 events)
# Processing batch 53 (100000 events)
# Processing batch 54 (100000 events)
# Processing batch 55 (100000 events)
# Processing batch 56 (100000 events)
# Processing batch 57 (100000 events)
# Processing batch 58 (100000 events)
# Processing batch 59 (100000 events)
# Processing batch 60 (100000 events)
# Processing batch 61 (100000 events)
# Processing batch 62 (100000 events)
# Processing batch 63 (100000 events)
# Processing batch 64 (100000 events)
# Processing batch 65 (100000 events)
# Processing batch 66 (100000 events)
# Processing batch 67 (100000 events)
# Processing batch 68 (100000 events)
# Processing batch 69 (100000 events)
# Processing batch 70 (100000 events)
# Processing batch 71 (100000 events)
# Processing batch 72 (100000 events)
# Processing batch 73 (100000 events)
# Processing batch 74 (100000 events)
# Processing batch 75 (100000 events)
# Processing batch 76 (100000 events)
# Processing batch 77 (100000 events)
# Processing batch 78 (100000 events)
# Processing batch 79 (100000 events)
# Processing batch 80 (100000 events)
# Processing batch 81 (100000 events)
# Processing batch 82 (100000 events)
# Processing batch 83 (100000 events)
# Processing batch 84 (100000 events)
# Processing batch 85 (100000 events)
# Processing batch 86 (100000 events)
# Processing batch 87 (100000 events)
# Processing batch 88 (100000 events)
# Processing batch 89 (100000 events)
# Processing batch 90 (100000 events)
# Processing batch 91 (100000 events)
# Processing batch 92 (100000 events)
# Processing batch 93 (100000 events)
# Processing batch 94 (100000 events)
# Processing batch 95 (100000 events)
# Processing batch 96 (100000 events)
# Processing batch 97 (100000 events)
# Processing batch 98 (100000 events)
# Processing batch 99 (100000 events)
# Processing batch 100 (100000 events)
# Processing batch 101 (100000 events)
# Processing batch 102 (100000 events)
# Processing batch 103 (100000 events)
# Processing batch 104 (100000 events)
# Processing batch 105 (100000 events)
# Processing batch 106 (100000 events)
# Processing batch 107 (100000 events)
# Processing batch 108 (100000 events)
# Processing batch 109 (100000 events)
# Processing batch 110 (100000 events)
# Processing batch 111 (100000 events)
# Processing batch 112 (100000 events)
# Processing batch 113 (100000 events)
# Processing batch 114 (100000 events)
# Processing batch 115 (100000 events)
# Processing batch 116 (100000 events)
# Processing batch 117 (100000 events)
# Processing batch 118 (100000 events)
# Processing batch 119 (100000 events)
# Processing batch 120 (100000 events)
# Processing batch 121 (100000 events)
# Processing batch 122 (100000 events)
# Processing batch 123 (100000 events)
# Processing batch 124 (100000 events)
# Processing batch 125 (100000 events)
# Processing batch 126 (100000 events)
# Processing batch 127 (100000 events)
# Processing batch 128 (100000 events)
# Processing batch 129 (100000 events)
# Processing batch 130 (100000 events)
# Processing batch 131 (100000 events)
# Processing batch 132 (100000 events)
# Processing batch 133 (100000 events)
# Processing batch 134 (100000 events)
# Processing batch 135 (100000 events)
# Processing batch 136 (100000 events)
# Processing batch 137 (100000 events)
# Processing batch 138 (100000 events)
# Processing batch 139 (100000 events)
# Processing batch 140 (100000 events)
# Processing batch 141 (100000 events)
# Processing batch 142 (100000 events)
# Processing batch 143 (100000 events)
# Processing batch 144 (100000 events)
# Processing batch 145 (100000 events)
# Processing batch 146 (100000 events)
# Processing batch 147 (100000 events)
# Processing batch 148 (100000 events)
# Processing batch 149 (100000 events)
# Processing batch 150 (100000 events)
# Processing batch 151 (100000 events)
# Processing batch 152 (100000 events)
# Processing batch 153 (100000 events)
# Processing batch 154 (100000 events)
# Processing batch 155 (100000 events)
# Processing batch 156 (100000 events)
# Processing batch 157 (100000 events)
# Processing batch 158 (100000 events)
# Processing batch 159 (100000 events)
# Processing batch 160 (100000 events)
# Processing batch 161 (100000 events)
# Processing batch 162 (100000 events)
# Processing batch 163 (100000 events)
# Processing batch 164 (100000 events)
# Processing batch 165 (100000 events)
# Processing batch 166 (100000 events)
# Processing batch 167 (100000 events)
# Processing batch 168 (100000 events)
# Processing batch 169 (100000 events)
# Processing batch 170 (100000 events)
# Processing batch 171 (100000 events)
# Processing batch 172 (100000 events)
# Processing batch 173 (100000 events)
# Processing batch 174 (100000 events)
# Processing batch 175 (100000 events)
# Processing batch 176 (100000 events)
# Processing batch 177 (100000 events)
# Processing batch 178 (100000 events)
# Processing batch 179 (100000 events)
# Processing batch 180 (100000 events)
# Processing batch 181 (100000 events)
# Processing batch 182 (100000 events)
# Processing batch 183 (100000 events)
# Processing batch 184 (100000 events)
# Processing batch 185 (100000 events)
# Processing batch 186 (100000 events)
# Processing batch 187 (100000 events)
# Processing batch 188 (100000 events)
# Processing batch 189 (100000 events)
# Processing batch 190 (100000 events)
# Processing batch 191 (100000 events)
# Processing batch 192 (100000 events)
# Processing batch 193 (100000 events)
# Processing batch 194 (100000 events)
# Processing batch 195 (100000 events)
# Processing batch 196 (100000 events)
# Processing batch 197 (100000 events)
# Processing batch 198 (100000 events)
# Processing batch 199 (100000 events)
# Processing batch 200 (100000 events)
# Processing batch 201 (100000 events)
# Processing batch 202 (100000 events)
# Processing batch 203 (100000 events)
# Processing batch 204 (100000 events)
# Processing batch 205 (100000 events)
# Processing batch 206 (100000 events)
# Processing batch 207 (100000 events)
# Processing batch 208 (100000 events)
# Processing batch 209 (100000 events)
# Processing batch 210 (100000 events)
# Processing batch 211 (100000 events)
# Processing batch 212 (100000 events)
# Processing batch 213 (100000 events)
# Processing batch 214 (100000 events)
# Processing batch 215 (100000 events)
# Processing batch 216 (100000 events)
# Processing batch 217 (100000 events)
# Processing batch 218 (100000 events)
# Processing batch 219 (100000 events)
# Processing batch 220 (100000 events)
# Processing batch 221 (100000 events)
# Processing batch 222 (100000 events)
# Processing batch 223 (100000 events)
# Processing batch 224 (100000 events)
# Processing batch 225 (100000 events)
# Processing batch 226 (100000 events)
# Processing batch 227 (100000 events)
# Processing batch 228 (100000 events)
# Processing batch 229 (100000 events)
# Processing batch 230 (100000 events)
# Processing batch 231 (100000 events)
# Processing batch 232 (100000 events)
# Processing batch 233 (100000 events)
# Processing batch 234 (100000 events)
# Processing batch 235 (100000 events)
# Processing batch 236 (100000 events)
# Processing batch 237 (100000 events)
# Processing batch 238 (100000 events)
# Processing batch 239 (100000 events)
# Processing batch 240 (100000 events)
# Processing batch 241 (100000 events)
# Processing batch 242 (100000 events)
# Processing batch 243 (100000 events)
# Processing batch 244 (100000 events)
# Processing batch 245 (100000 events)
# Processing batch 246 (100000 events)
# Processing batch 247 (100000 events)
# Processing batch 248 (100000 events)
# Processing batch 249 (100000 events)
# Processing batch 250 (100000 events)
# Processing batch 251 (100000 events)
# Processing batch 252 (100000 events)
# Processing batch 253 (100000 events)
# Processing batch 254 (100000 events)
# Processing batch 255 (100000 events)
# Processing batch 256 (100000 events)
# Processing batch 257 (100000 events)
# Processing batch 258 (100000 events)
# Processing batch 259 (100000 events)
# Processing batch 260 (100000 events)
# Processing batch 261 (100000 events)
# Processing batch 262 (100000 events)
# Processing batch 263 (100000 events)
# Processing batch 264 (100000 events)
# Processing batch 265 (100000 events)
# Processing batch 266 (100000 events)
# Processing batch 267 (100000 events)
# Processing batch 268 (100000 events)
# Processing batch 269 (100000 events)
# Processing batch 270 (100000 events)
# Processing batch 271 (100000 events)
# Processing batch 272 (100000 events)
# Processing batch 273 (100000 events)
# Processing batch 274 (100000 events)
# Processing batch 275 (100000 events)
# Processing batch 276 (100000 events)
# Processing batch 277 (100000 events)
# Processing batch 278 (100000 events)
# Processing batch 279 (100000 events)
# Processing batch 280 (100000 events)
# Processing batch 281 (100000 events)
# Processing batch 282 (100000 events)
# Processing batch 283 (100000 events)
# Processing batch 284 (100000 events)
# Processing batch 285 (100000 events)
# Processing batch 286 (100000 events)
# Processing batch 287 (100000 events)
# Processing batch 288 (100000 events)
# Processing batch 289 (100000 events)
# Processing batch 290 (100000 events)
# Processing batch 291 (100000 events)
# Processing batch 292 (100000 events)
# Processing batch 293 (100000 events)
# Processing batch 294 (100000 events)
# Processing batch 295 (100000 events)
# Processing batch 296 (100000 events)
# Processing batch 297 (100000 events)
# Processing batch 298 (100000 events)
# Processing batch 299 (100000 events)
# Processing batch 300 (100000 events)
# Processing batch 301 (100000 events)
# Processing batch 302 (100000 events)
# Processing batch 303 (100000 events)
# Processing batch 304 (100000 events)
# Processing batch 305 (100000 events)
# Processing batch 306 (100000 events)
# Processing batch 307 (100000 events)
# Processing batch 308 (100000 events)
# Processing batch 309 (100000 events)
# Processing batch 310 (100000 events)
# Processing batch 311 (100000 events)
# Processing batch 312 (100000 events)
# Processing batch 313 (100000 events)
# Processing batch 314 (100000 events)
# Processing batch 315 (100000 events)
# Processing batch 316 (100000 events)
# Processing batch 317 (100000 events)
# Processing batch 318 (100000 events)
# Processing batch 319 (100000 events)
# Processing batch 320 (100000 events)
# Processing batch 321 (100000 events)
# Processing batch 322 (100000 events)
# Processing batch 323 (100000 events)
# Processing batch 324 (100000 events)
# Processing batch 325 (100000 events)
# Processing batch 326 (100000 events)
# Processing batch 327 (100000 events)
# Processing batch 328 (100000 events)
# Processing batch 329 (100000 events)
# Processing batch 330 (100000 events)
# Processing batch 331 (100000 events)
# Processing batch 332 (100000 events)
# Processing batch 333 (100000 events)
# Processing batch 334 (100000 events)
# Processing batch 335 (100000 events)
# Processing batch 336 (100000 events)
# Processing batch 337 (100000 events)
# Processing batch 338 (100000 events)
# Processing batch 339 (100000 events)
# Processing batch 340 (100000 events)
# Processing batch 341 (100000 events)
# Processing batch 342 (100000 events)
# Processing batch 343 (100000 events)
# Processing batch 344 (100000 events)
# Processing batch 345 (100000 events)
# Processing batch 346 (100000 events)
# Processing batch 347 (100000 events)
# Processing batch 348 (100000 events)
# Processing batch 349 (100000 events)
# Processing batch 350 (100000 events)
# Processing batch 351 (100000 events)
# Processing batch 352 (100000 events)
# Processing batch 353 (100000 events)
# Processing batch 354 (100000 events)
# Processing batch 355 (100000 events)
# Processing batch 356 (100000 events)
# Processing batch 357 (100000 events)
# Processing batch 358 (100000 events)
# Processing batch 359 (100000 events)
# Processing batch 360 (100000 events)
# Processing batch 361 (100000 events)
# Processing batch 362 (100000 events)
# Processing batch 363 (100000 events)
# Processing batch 364 (100000 events)
# Processing batch 365 (100000 events)
# Processing batch 366 (100000 events)
# Processing batch 367 (100000 events)
# Processing batch 368 (100000 events)
# Processing batch 369 (100000 events)
# Processing batch 370 (100000 events)
# Processing batch 371 (100000 events)
# Processing batch 372 (100000 events)
# Processing batch 373 (100000 events)
# Processing batch 374 (100000 events)
# Processing batch 375 (100000 events)
# Processing batch 376 (100000 events)
# Processing batch 377 (100000 events)
# Processing batch 378 (100000 events)
# Processing batch 379 (100000 events)
# Processing batch 380 (100000 events)
# Processing batch 381 (100000 events)
# Processing batch 382 (100000 events)
# Processing batch 383 (100000 events)
# Processing batch 384 (100000 events)
# Processing batch 385 (100000 events)
# Processing batch 386 (100000 events)
# Processing batch 387 (100000 events)
# Processing batch 388 (100000 events)
# Processing batch 389 (100000 events)
# Processing batch 390 (100000 events)
# Processing batch 391 (100000 events)
# Processing batch 392 (100000 events)
# Processing batch 393 (100000 events)
# Processing batch 394 (100000 events)
# Processing batch 395 (100000 events)
# Processing batch 396 (100000 events)
# Processing batch 397 (100000 events)
# Processing batch 398 (100000 events)
# Processing batch 399 (100000 events)
# Processing batch 400 (100000 events)
# Processing batch 401 (100000 events)
# Processing batch 402 (100000 events)
# Processing batch 403 (100000 events)
# Processing batch 404 (100000 events)
# Processing batch 405 (100000 events)
# Processing batch 406 (100000 events)
# Processing batch 407 (100000 events)
# Processing batch 408 (100000 events)
# Processing batch 409 (100000 events)
# Processing batch 410 (100000 events)
# Processing batch 411 (100000 events)
# Processing batch 412 (100000 events)
# Processing batch 413 (100000 events)
# Processing batch 414 (100000 events)
# Processing batch 415 (100000 events)
# Processing batch 416 (100000 events)
# Processing batch 417 (100000 events)
# Processing batch 418 (100000 events)
# Processing batch 419 (100000 events)
# Processing batch 420 (100000 events)
# Processing batch 421 (100000 events)
# Processing batch 422 (100000 events)
# Processing batch 423 (100000 events)
# Processing batch 424 (100000 events)
# Processing batch 425 (100000 events)
# Processing batch 426 (100000 events)
# Processing batch 427 (100000 events)
# Processing batch 428 (100000 events)
# Processing batch 429 (100000 events)
# Processing batch 430 (100000 events)
# Processing batch 431 (100000 events)
# Processing batch 432 (100000 events)
# Processing batch 433 (100000 events)
# Processing batch 434 (100000 events)
# Processing batch 435 (100000 events)
# Processing batch 436 (100000 events)
# Processing batch 437 (100000 events)
# Processing batch 438 (100000 events)
# Processing batch 439 (100000 events)
# Processing batch 440 (100000 events)
# Processing batch 441 (100000 events)
# Processing batch 442 (100000 events)
# Processing batch 443 (100000 events)
# Processing batch 444 (100000 events)
# Processing batch 445 (100000 events)
# Processing batch 446 (100000 events)
# Processing batch 447 (100000 events)
# Processing batch 448 (100000 events)
# Processing batch 449 (100000 events)
# Processing batch 450 (100000 events)
# Processing batch 451 (100000 events)
# Processing batch 452 (100000 events)
# Processing batch 453 (100000 events)
# Processing batch 454 (100000 events)
# Processing batch 455 (100000 events)
# Processing batch 456 (100000 events)
# Processing batch 457 (100000 events)
# Processing batch 458 (100000 events)
# Processing batch 459 (100000 events)
# Processing batch 460 (100000 events)
# Processing batch 461 (100000 events)
# Processing batch 462 (100000 events)
# Processing batch 463 (100000 events)
# Processing batch 464 (100000 events)
# Processing batch 465 (100000 events)
# Processing batch 466 (100000 events)
# Processing batch 467 (100000 events)
# Processing batch 468 (100000 events)
# Processing batch 469 (100000 events)
# Processing batch 470 (100000 events)
# Processing batch 471 (100000 events)
# Processing batch 472 (100000 events)
# Processing batch 473 (100000 events)
# Processing batch 474 (100000 events)
# Processing batch 475 (100000 events)
# Processing batch 476 (100000 events)
# Processing batch 477 (100000 events)
# Processing batch 478 (100000 events)
# Processing batch 479 (100000 events)
# Processing batch 480 (100000 events)
# Processing batch 481 (100000 events)
# Processing batch 482 (100000 events)
# Processing batch 483 (100000 events)
# Processing batch 484 (100000 events)
# Processing batch 485 (100000 events)
# Processing batch 486 (100000 events)
# Processing batch 487 (100000 events)
# Processing batch 488 (100000 events)
# Processing batch 489 (100000 events)
# Processing batch 490 (100000 events)
# Processing batch 491 (100000 events)
# Processing batch 492 (100000 events)
# Processing batch 493 (100000 events)
# Processing batch 494 (100000 events)
# Processing batch 495 (100000 events)
# Processing batch 496 (100000 events)
# Processing batch 497 (100000 events)
# Processing batch 498 (100000 events)
# Processing batch 499 (100000 events)
# Processing batch 500 (100000 events)
# Processing batch 501 (100000 events)
# Processing batch 502 (100000 events)
# Processing batch 503 (100000 events)
# Processing batch 504 (100000 events)
# Processing batch 505 (100000 events)
# Processing batch 506 (100000 events)
# Processing batch 507 (100000 events)
# Processing batch 508 (100000 events)
# Processing batch 509 (100000 events)
# Processing batch 510 (100000 events)
# Processing batch 511 (100000 events)
# Processing batch 512 (100000 events)
# Processing batch 513 (100000 events)
# Processing batch 514 (100000 events)
# Processing batch 515 (100000 events)
# Processing batch 516 (100000 events)
# Processing batch 517 (100000 events)
# Processing batch 518 (100000 events)
# Processing batch 519 (100000 events)
# Processing batch 520 (100000 events)
# Processing batch 521 (100000 events)
# Processing batch 522 (100000 events)
# Processing batch 523 (100000 events)
# Processing batch 524 (100000 events)
# Processing batch 525 (100000 events)
# Processing batch 526 (100000 events)
# Processing batch 527 (100000 events)
# Processing batch 528 (100000 events)
# Processing batch 529 (100000 events)
# Processing batch 530 (100000 events)
# Processing batch 531 (100000 events)
# Processing batch 532 (100000 events)
# Processing batch 533 (100000 events)
# Processing batch 534 (100000 events)
# Processing batch 535 (100000 events)
# Processing batch 536 (100000 events)
# Processing batch 537 (100000 events)
# Processing batch 538 (100000 events)
# Processing batch 539 (100000 events)
# Processing batch 540 (100000 events)
# Processing batch 541 (100000 events)
# Processing batch 542 (100000 events)
# Processing batch 543 (100000 events)
# Processing batch 544 (100000 events)
# Processing batch 545 (100000 events)
# Processing batch 546 (100000 events)
# Processing batch 547 (100000 events)
# Processing batch 548 (100000 events)
# Processing batch 549 (100000 events)
# Processing batch 550 (100000 events)
# Processing batch 551 (100000 events)
# Processing batch 552 (100000 events)
# Processing batch 553 (100000 events)
# Processing batch 554 (100000 events)
# Processing batch 555 (100000 events)
# Processing batch 556 (100000 events)
# Processing batch 557 (100000 events)
# Processing batch 558 (100000 events)
# Processing batch 559 (100000 events)
# Processing batch 560 (100000 events)
# Processing batch 561 (100000 events)
# Processing batch 562 (100000 events)
# Processing batch 563 (100000 events)
# Processing batch 564 (100000 events)
# Processing batch 565 (100000 events)
# Processing batch 566 (100000 events)
# Processing batch 567 (100000 events)
# Processing batch 568 (100000 events)
# Processing batch 569 (100000 events)
# Processing batch 570 (100000 events)
# Processing batch 571 (100000 events)
# Processing batch 572 (100000 events)
# Processing batch 573 (100000 events)
# Processing batch 574 (100000 events)
# Processing batch 575 (100000 events)
# Processing batch 576 (100000 events)
# Processing batch 577 (100000 events)
# Processing batch 578 (100000 events)
# Processing batch 579 (100000 events)
# Processing batch 580 (100000 events)
# Processing batch 581 (100000 events)
# Processing batch 582 (100000 events)
# Processing batch 583 (100000 events)
# Processing batch 584 (100000 events)
# Processing batch 585 (100000 events)
# Processing batch 586 (100000 events)
# Processing batch 587 (100000 events)
# Processing batch 588 (100000 events)
# Processing batch 589 (100000 events)
# Processing batch 590 (100000 events)
# Processing batch 591 (100000 events)
# Processing batch 592 (100000 events)
# Processing batch 593 (100000 events)
# Processing batch 594 (100000 events)
# Processing batch 595 (100000 events)
# Processing batch 596 (100000 events)
# Processing batch 597 (100000 events)
# Processing batch 598 (100000 events)
# Processing batch 599 (100000 events)
# Processing batch 600 (100000 events)
# Processing batch 601 (100000 events)
# Processing batch 602 (100000 events)
# Processing batch 603 (100000 events)
# Processing batch 604 (100000 events)
# Processing batch 605 (100000 events)
# Processing batch 606 (100000 events)
# Processing batch 607 (100000 events)
# Processing batch 608 (100000 events)
# Processing batch 609 (100000 events)
# Processing batch 610 (100000 events)
# Processing batch 611 (100000 events)
# Processing batch 612 (100000 events)
# Processing batch 613 (100000 events)
# Processing batch 614 (100000 events)
# Processing batch 615 (100000 events)
# Processing batch 616 (100000 events)
# Processing batch 617 (100000 events)
# Processing batch 618 (100000 events)
# Processing batch 619 (100000 events)
# Processing batch 620 (100000 events)
# Processing batch 621 (100000 events)
# Processing batch 622 (100000 events)
# Processing batch 623 (100000 events)
# Processing batch 624 (100000 events)
# Processing batch 625 (100000 events)
# Processing batch 626 (100000 events)
# Processing batch 627 (100000 events)
# Processing batch 628 (100000 events)
# Processing batch 629 (100000 events)
# Processing batch 630 (100000 events)
# Processing batch 631 (100000 events)
# Processing batch 632 (100000 events)
# Processing batch 633 (100000 events)
# Processing batch 634 (100000 events)
# Processing batch 635 (100000 events)
# Processing batch 636 (100000 events)
# Processing batch 637 (100000 events)
# Processing batch 638 (100000 events)
# Processing batch 639 (100000 events)
# Processing batch 640 (100000 events)
# Processing batch 641 (100000 events)
# Processing batch 642 (100000 events)
# Processing batch 643 (100000 events)
# Processing batch 644 (100000 events)
# Processing batch 645 (100000 events)
# Processing batch 646 (100000 events)
# Processing batch 647 (100000 events)
# Processing batch 648 (100000 events)
# Processing batch 649 (100000 events)
# Processing batch 650 (100000 events)
# Processing batch 651 (100000 events)
# Processing batch 652 (100000 events)
# Processing batch 653 (100000 events)
# Processing batch 654 (100000 events)
# Processing batch 655 (100000 events)
# Processing batch 656 (100000 events)
# Processing batch 657 (100000 events)
# Processing batch 658 (100000 events)
# Processing batch 659 (100000 events)
# Processing batch 660 (100000 events)
# Processing batch 661 (100000 events)
# Processing batch 662 (100000 events)
# Processing batch 663 (100000 events)
# Processing batch 664 (100000 events)
# Processing batch 665 (100000 events)
# Processing batch 666 (100000 events)
# Processing batch 667 (100000 events)
# Processing batch 668 (100000 events)
# Processing batch 669 (100000 events)
# Processing batch 670 (100000 events)
# Processing batch 671 (100000 events)
# Processing batch 672 (100000 events)
# Processing batch 673 (100000 events)
# Processing batch 674 (100000 events)
# Processing batch 675 (100000 events)
# Processing batch 676 (100000 events)
# Processing batch 677 (100000 events)
# Processing batch 678 (100000 events)
# Processing batch 679 (100000 events)
# Processing batch 680 (100000 events)
# Processing batch 681 (100000 events)
# Processing batch 682 (100000 events)
# Processing batch 683 (100000 events)
# Processing batch 684 (100000 events)
# Processing batch 685 (100000 events)
# Processing batch 686 (100000 events)
# Processing batch 687 (100000 events)
# Processing batch 688 (100000 events)
# Processing batch 689 (100000 events)
# Processing batch 690 (100000 events)
# Processing batch 691 (100000 events)
# Processing batch 692 (100000 events)
# Processing batch 693 (100000 events)
# Processing batch 694 (100000 events)
# Processing batch 695 (100000 events)
# Processing batch 696 (100000 events)
# Processing batch 697 (100000 events)
# Processing batch 698 (100000 events)
# Processing batch 699 (100000 events)
# Processing batch 700 (100000 events)
# Processing batch 701 (100000 events)
# Processing batch 702 (100000 events)
# Processing batch 703 (100000 events)
# Processing batch 704 (100000 events)
# Processing batch 705 (100000 events)
# Processing batch 706 (100000 events)
# Processing batch 707 (100000 events)
# Processing batch 708 (100000 events)
# Processing batch 709 (100000 events)
# Processing batch 710 (100000 events)
# Processing batch 711 (100000 events)
# Processing batch 712 (100000 events)
# Processing batch 713 (100000 events)
# Processing batch 714 (100000 events)
# Processing batch 715 (100000 events)
# Processing batch 716 (100000 events)
# Processing batch 717 (100000 events)
# Processing batch 718 (100000 events)
# Processing batch 719 (100000 events)
# Processing batch 720 (100000 events)
# Processing batch 721 (100000 events)
# Processing batch 722 (100000 events)
# Processing batch 723 (100000 events)
# Processing batch 724 (100000 events)
# Processing batch 725 (100000 events)
# Processing batch 726 (100000 events)
# Processing batch 727 (100000 events)
# Processing batch 728 (100000 events)
# Processing batch 729 (100000 events)
# Processing batch 730 (100000 events)
# Processing batch 731 (100000 events)
# Processing batch 732 (100000 events)
# Processing batch 733 (100000 events)
# Processing batch 734 (100000 events)
# Processing batch 735 (100000 events)
# Processing batch 736 (100000 events)
# Processing batch 737 (100000 events)
# Processing batch 738 (100000 events)
# Processing batch 739 (100000 events)
# Processing batch 740 (100000 events)
# Processing batch 741 (100000 events)
# Processing batch 742 (100000 events)
# Processing batch 743 (100000 events)
# Processing batch 744 (100000 events)
# Processing batch 745 (100000 events)
# Processing batch 746 (100000 events)
# Processing batch 747 (100000 events)
# Processing batch 748 (100000 events)
# Processing batch 749 (100000 events)
# Processing batch 750 (100000 events)
# Processing batch 751 (100000 events)
# Processing batch 752 (100000 events)
# Processing batch 753 (100000 events)
# Processing batch 754 (100000 events)
# Processing batch 755 (100000 events)
# Processing batch 756 (100000 events)
# Processing batch 757 (100000 events)
# Processing batch 758 (100000 events)
# Processing batch 759 (100000 events)
# Processing batch 760 (100000 events)
# Processing batch 761 (100000 events)
# Processing batch 762 (100000 events)
# Processing batch 763 (100000 events)
# Processing batch 764 (100000 events)
# Processing batch 765 (100000 events)
# Processing batch 766 (100000 events)
# Processing batch 767 (100000 events)
# Processing batch 768 (100000 events)
# Processing batch 769 (100000 events)
# Processing batch 770 (100000 events)
# Processing batch 771 (100000 events)
# Processing batch 772 (100000 events)
# Processing batch 773 (100000 events)
# Processing batch 774 (100000 events)
# Processing batch 775 (100000 events)
# Processing batch 776 (100000 events)
# Processing batch 777 (100000 events)
# Processing batch 778 (100000 events)
# Processing batch 779 (100000 events)
# Processing batch 780 (100000 events)
# Processing batch 781 (100000 events)
# Processing batch 782 (100000 events)
# Processing batch 783 (100000 events)
# Processing batch 784 (100000 events)
# Processing batch 785 (100000 events)
# Processing batch 786 (100000 events)
# Processing batch 787 (100000 events)
# Processing batch 788 (100000 events)
# Processing batch 789 (100000 events)
# Processing batch 790 (100000 events)
# Processing batch 791 (100000 events)
# Processing batch 792 (100000 events)
# Processing batch 793 (100000 events)
# Processing batch 794 (100000 events)
# Processing batch 795 (100000 events)
# Processing batch 796 (100000 events)
# Processing batch 797 (100000 events)
# Processing batch 798 (100000 events)
# Processing batch 799 (100000 events)
# Processing batch 800 (100000 events)
# Processing batch 801 (100000 events)
# Processing batch 802 (100000 events)
# Processing batch 803 (100000 events)
# Processing batch 804 (100000 events)
# Processing batch 805 (100000 events)
# Processing batch 806 (100000 events)
# Processing batch 807 (100000 events)
# Processing batch 808 (100000 events)
# Processing batch 809 (100000 events)
# Processing batch 810 (100000 events)
# Processing batch 811 (100000 events)
# Processing batch 812 (100000 events)
# Processing batch 813 (100000 events)
# Processing batch 814 (100000 events)
# Processing batch 815 (100000 events)
# Processing batch 816 (100000 events)
# Processing batch 817 (32177 events)
# e-mu events after channel selection: 67742
# Events after global selection: 7948
# Events in 0-jet category: 145
#
# Processing file: TTBar.root (Top antitop)
#
# Processing: TTBar.root
# Total events: 42229000
# Processing batch 1 (100000 events)
# Processing batch 2 (100000 events)
# Processing batch 3 (100000 events)
# Processing batch 4 (100000 events)
# Processing batch 5 (100000 events)
# Processing batch 6 (100000 events)
# Processing batch 7 (100000 events)
# Processing batch 8 (100000 events)
# Processing batch 9 (100000 events)
# Processing batch 10 (100000 events)
# Processing batch 11 (100000 events)
# Processing batch 12 (100000 events)
# Processing batch 13 (100000 events)
# Processing batch 14 (100000 events)
# Processing batch 15 (100000 events)
# Processing batch 16 (100000 events)
# Processing batch 17 (100000 events)
# Processing batch 18 (100000 events)
# Processing batch 19 (100000 events)
# Processing batch 20 (100000 events)
# Processing batch 21 (100000 events)
# Processing batch 22 (100000 events)
# Processing batch 23 (100000 events)
# Processing batch 24 (100000 events)
# Processing batch 25 (100000 events)
# Processing batch 26 (100000 events)
# Processing batch 27 (100000 events)
# Processing batch 28 (100000 events)
# Processing batch 29 (100000 events)
# Processing batch 30 (100000 events)
# Processing batch 31 (100000 events)
# Processing batch 32 (100000 events)
# Processing batch 33 (100000 events)
# Processing batch 34 (100000 events)
# Processing batch 35 (100000 events)
# Processing batch 36 (100000 events)
# Processing batch 37 (100000 events)
# Processing batch 38 (100000 events)
# Processing batch 39 (100000 events)
# Processing batch 40 (100000 events)
# Processing batch 41 (100000 events)
# Processing batch 42 (100000 events)
# Processing batch 43 (100000 events)
# Processing batch 44 (100000 events)
# Processing batch 45 (100000 events)
# Processing batch 46 (100000 events)
# Processing batch 47 (100000 events)
# Processing batch 48 (100000 events)
# Processing batch 49 (100000 events)
# Processing batch 50 (100000 events)
# Processing batch 51 (100000 events)
# Processing batch 52 (100000 events)
# Processing batch 53 (100000 events)
# Processing batch 54 (100000 events)
# Processing batch 55 (100000 events)
# Processing batch 56 (100000 events)
# Processing batch 57 (100000 events)
# Processing batch 58 (100000 events)
# Processing batch 59 (100000 events)
# Processing batch 60 (100000 events)
# Processing batch 61 (100000 events)
# Processing batch 62 (100000 events)
# Processing batch 63 (100000 events)
# Processing batch 64 (100000 events)
# Processing batch 65 (100000 events)
# Processing batch 66 (100000 events)
# Processing batch 67 (100000 events)
# Processing batch 68 (100000 events)
# Processing batch 69 (100000 events)
# Processing batch 70 (100000 events)
# Processing batch 71 (100000 events)
# Processing batch 72 (100000 events)
# Processing batch 73 (100000 events)
# Processing batch 74 (100000 events)
# Processing batch 75 (100000 events)
# Processing batch 76 (100000 events)
# Processing batch 77 (100000 events)
# Processing batch 78 (100000 events)
# Processing batch 79 (100000 events)
# Processing batch 80 (100000 events)
# Processing batch 81 (100000 events)
# Processing batch 82 (100000 events)
# Processing batch 83 (100000 events)
# Processing batch 84 (100000 events)
# Processing batch 85 (100000 events)
# Processing batch 86 (100000 events)
# Processing batch 87 (100000 events)
# Processing batch 88 (100000 events)
# Processing batch 89 (100000 events)
# Processing batch 90 (100000 events)
# Processing batch 91 (100000 events)
# Processing batch 92 (100000 events)
# Processing batch 93 (100000 events)
# Processing batch 94 (100000 events)
# Processing batch 95 (100000 events)
# Processing batch 96 (100000 events)
# Processing batch 97 (100000 events)
# Processing batch 98 (100000 events)
# Processing batch 99 (100000 events)
# Processing batch 100 (100000 events)
# Processing batch 101 (100000 events)
# Processing batch 102 (100000 events)
# Processing batch 103 (100000 events)
# Processing batch 104 (100000 events)
# Processing batch 105 (100000 events)
# Processing batch 106 (100000 events)
# Processing batch 107 (100000 events)
# Processing batch 108 (100000 events)
# Processing batch 109 (100000 events)
# Processing batch 110 (100000 events)
# Processing batch 111 (100000 events)
# Processing batch 112 (100000 events)
# Processing batch 113 (100000 events)
# Processing batch 114 (100000 events)
# Processing batch 115 (100000 events)
# Processing batch 116 (100000 events)
# Processing batch 117 (100000 events)
# Processing batch 118 (100000 events)
# Processing batch 119 (100000 events)
# Processing batch 120 (100000 events)
# Processing batch 121 (100000 events)
# Processing batch 122 (100000 events)
# Processing batch 123 (100000 events)
# Processing batch 124 (100000 events)
# Processing batch 125 (100000 events)
# Processing batch 126 (100000 events)
# Processing batch 127 (100000 events)
# Processing batch 128 (100000 events)
# Processing batch 129 (100000 events)
# Processing batch 130 (100000 events)
# Processing batch 131 (100000 events)
# Processing batch 132 (100000 events)
# Processing batch 133 (100000 events)
# Processing batch 134 (100000 events)
# Processing batch 135 (100000 events)
# Processing batch 136 (100000 events)
# Processing batch 137 (100000 events)
# Processing batch 138 (100000 events)
# Processing batch 139 (100000 events)
# Processing batch 140 (100000 events)
# Processing batch 141 (100000 events)
# Processing batch 142 (100000 events)
# Processing batch 143 (100000 events)
# Processing batch 144 (100000 events)
# Processing batch 145 (100000 events)
# Processing batch 146 (100000 events)
# Processing batch 147 (100000 events)
# Processing batch 148 (100000 events)
# Processing batch 149 (100000 events)
# Processing batch 150 (100000 events)
# Processing batch 151 (100000 events)
# Processing batch 152 (100000 events)
# Processing batch 153 (100000 events)
# Processing batch 154 (100000 events)
# Processing batch 155 (100000 events)
# Processing batch 156 (100000 events)
# Processing batch 157 (100000 events)
# Processing batch 158 (100000 events)
# Processing batch 159 (100000 events)
# Processing batch 160 (100000 events)
# Processing batch 161 (100000 events)
# Processing batch 162 (100000 events)
# Processing batch 163 (100000 events)
# Processing batch 164 (100000 events)
# Processing batch 165 (100000 events)
# Processing batch 166 (100000 events)
# Processing batch 167 (100000 events)
# Processing batch 168 (100000 events)
# Processing batch 169 (100000 events)
# Processing batch 170 (100000 events)
# Processing batch 171 (100000 events)
# Processing batch 172 (100000 events)
# Processing batch 173 (100000 events)
# Processing batch 174 (100000 events)
# Processing batch 175 (100000 events)
# Processing batch 176 (100000 events)
# Processing batch 177 (100000 events)
# Processing batch 178 (100000 events)
# Processing batch 179 (100000 events)
# Processing batch 180 (100000 events)
# Processing batch 181 (100000 events)
# Processing batch 182 (100000 events)
# Processing batch 183 (100000 events)
# Processing batch 184 (100000 events)
# Processing batch 185 (100000 events)
# Processing batch 186 (100000 events)
# Processing batch 187 (100000 events)
# Processing batch 188 (100000 events)
# Processing batch 189 (100000 events)
# Processing batch 190 (100000 events)
# Processing batch 191 (100000 events)
# Processing batch 192 (100000 events)
# Processing batch 193 (100000 events)
# Processing batch 194 (100000 events)
# Processing batch 195 (100000 events)
# Processing batch 196 (100000 events)
# Processing batch 197 (100000 events)
# Processing batch 198 (100000 events)
# Processing batch 199 (100000 events)
# Processing batch 200 (100000 events)
# Processing batch 201 (100000 events)
# Processing batch 202 (100000 events)
# Processing batch 203 (100000 events)
# Processing batch 204 (100000 events)
# Processing batch 205 (100000 events)
# Processing batch 206 (100000 events)
# Processing batch 207 (100000 events)
# Processing batch 208 (100000 events)
# Processing batch 209 (100000 events)
# Processing batch 210 (100000 events)
# Processing batch 211 (100000 events)
# Processing batch 212 (100000 events)
# Processing batch 213 (100000 events)
# Processing batch 214 (100000 events)
# Processing batch 215 (100000 events)
# Processing batch 216 (100000 events)
# Processing batch 217 (100000 events)
# Processing batch 218 (100000 events)
# Processing batch 219 (100000 events)
# Processing batch 220 (100000 events)
# Processing batch 221 (100000 events)
# Processing batch 222 (100000 events)
# Processing batch 223 (100000 events)
# Processing batch 224 (100000 events)
# Processing batch 225 (100000 events)
# Processing batch 226 (100000 events)
# Processing batch 227 (100000 events)
# Processing batch 228 (100000 events)
# Processing batch 229 (100000 events)
# Processing batch 230 (100000 events)
# Processing batch 231 (100000 events)
# Processing batch 232 (100000 events)
# Processing batch 233 (100000 events)
# Processing batch 234 (100000 events)
# Processing batch 235 (100000 events)
# Processing batch 236 (100000 events)
# Processing batch 237 (100000 events)
# Processing batch 238 (100000 events)
# Processing batch 239 (100000 events)
# Processing batch 240 (100000 events)
# Processing batch 241 (100000 events)
# Processing batch 242 (100000 events)
# Processing batch 243 (100000 events)
# Processing batch 244 (100000 events)
# Processing batch 245 (100000 events)
# Processing batch 246 (100000 events)
# Processing batch 247 (100000 events)
# Processing batch 248 (100000 events)
# Processing batch 249 (100000 events)
# Processing batch 250 (100000 events)
# Processing batch 251 (100000 events)
# Processing batch 252 (100000 events)
# Processing batch 253 (100000 events)
# Processing batch 254 (100000 events)
# Processing batch 255 (100000 events)
# Processing batch 256 (100000 events)
# Processing batch 257 (100000 events)
# Processing batch 258 (100000 events)
# Processing batch 259 (100000 events)
# Processing batch 260 (100000 events)
# Processing batch 261 (100000 events)
# Processing batch 262 (100000 events)
# Processing batch 263 (100000 events)
# Processing batch 264 (100000 events)
# Processing batch 265 (100000 events)
# Processing batch 266 (100000 events)
# Processing batch 267 (100000 events)
# Processing batch 268 (100000 events)
# Processing batch 269 (100000 events)
# Processing batch 270 (100000 events)
# Processing batch 271 (100000 events)
# Processing batch 272 (100000 events)
# Processing batch 273 (100000 events)
# Processing batch 274 (100000 events)
# Processing batch 275 (100000 events)
# Processing batch 276 (100000 events)
# Processing batch 277 (100000 events)
# Processing batch 278 (100000 events)
# Processing batch 279 (100000 events)
# Processing batch 280 (100000 events)
# Processing batch 281 (100000 events)
# Processing batch 282 (100000 events)
# Processing batch 283 (100000 events)
# Processing batch 284 (100000 events)
# Processing batch 285 (100000 events)
# Processing batch 286 (100000 events)
# Processing batch 287 (100000 events)
# Processing batch 288 (100000 events)
# Processing batch 289 (100000 events)
# Processing batch 290 (100000 events)
# Processing batch 291 (100000 events)
# Processing batch 292 (100000 events)
# Processing batch 293 (100000 events)
# Processing batch 294 (100000 events)
# Processing batch 295 (100000 events)
# Processing batch 296 (100000 events)
# Processing batch 297 (100000 events)
# Processing batch 298 (100000 events)
# Processing batch 299 (100000 events)
# Processing batch 300 (100000 events)
# Processing batch 301 (100000 events)
# Processing batch 302 (100000 events)
# Processing batch 303 (100000 events)
# Processing batch 304 (100000 events)
# Processing batch 305 (100000 events)
# Processing batch 306 (100000 events)
# Processing batch 307 (100000 events)
# Processing batch 308 (100000 events)
# Processing batch 309 (100000 events)
# Processing batch 310 (100000 events)
# Processing batch 311 (100000 events)
# Processing batch 312 (100000 events)
# Processing batch 313 (100000 events)
# Processing batch 314 (100000 events)
# Processing batch 315 (100000 events)
# Processing batch 316 (100000 events)
# Processing batch 317 (100000 events)
# Processing batch 318 (100000 events)
# Processing batch 319 (100000 events)
# Processing batch 320 (100000 events)
# Processing batch 321 (100000 events)
# Processing batch 322 (100000 events)
# Processing batch 323 (100000 events)
# Processing batch 324 (100000 events)
# Processing batch 325 (100000 events)
# Processing batch 326 (100000 events)
# Processing batch 327 (100000 events)
# Processing batch 328 (100000 events)
# Processing batch 329 (100000 events)
# Processing batch 330 (100000 events)
# Processing batch 331 (100000 events)
# Processing batch 332 (100000 events)
# Processing batch 333 (100000 events)
# Processing batch 334 (100000 events)
# Processing batch 335 (100000 events)
# Processing batch 336 (100000 events)
# Processing batch 337 (100000 events)
# Processing batch 338 (100000 events)
# Processing batch 339 (100000 events)
# Processing batch 340 (100000 events)
# Processing batch 341 (100000 events)
# Processing batch 342 (100000 events)
# Processing batch 343 (100000 events)
# Processing batch 344 (100000 events)
# Processing batch 345 (100000 events)
# Processing batch 346 (100000 events)
# Processing batch 347 (100000 events)
# Processing batch 348 (100000 events)
# Processing batch 349 (100000 events)
# Processing batch 350 (100000 events)
# Processing batch 351 (100000 events)
# Processing batch 352 (100000 events)
# Processing batch 353 (100000 events)
# Processing batch 354 (100000 events)
# Processing batch 355 (100000 events)
# Processing batch 356 (100000 events)
# Processing batch 357 (100000 events)
# Processing batch 358 (100000 events)
# Processing batch 359 (100000 events)
# Processing batch 360 (100000 events)
# Processing batch 361 (100000 events)
# Processing batch 362 (100000 events)
# Processing batch 363 (100000 events)
# Processing batch 364 (100000 events)
# Processing batch 365 (100000 events)
# Processing batch 366 (100000 events)
# Processing batch 367 (100000 events)
# Processing batch 368 (100000 events)
# Processing batch 369 (100000 events)
# Processing batch 370 (100000 events)
# Processing batch 371 (100000 events)
# Processing batch 372 (100000 events)
# Processing batch 373 (100000 events)
# Processing batch 374 (100000 events)
# Processing batch 375 (100000 events)
# Processing batch 376 (100000 events)
# Processing batch 377 (100000 events)
# Processing batch 378 (100000 events)
# Processing batch 379 (100000 events)
# Processing batch 380 (100000 events)
# Processing batch 381 (100000 events)
# Processing batch 382 (100000 events)
# Processing batch 383 (100000 events)
# Processing batch 384 (100000 events)
# Processing batch 385 (100000 events)
# Processing batch 386 (100000 events)
# Processing batch 387 (100000 events)
# Processing batch 388 (100000 events)
# Processing batch 389 (100000 events)
# Processing batch 390 (100000 events)
# Processing batch 391 (100000 events)
# Processing batch 392 (100000 events)
# Processing batch 393 (100000 events)
# Processing batch 394 (100000 events)
# Processing batch 395 (100000 events)
# Processing batch 396 (100000 events)
# Processing batch 397 (100000 events)
# Processing batch 398 (100000 events)
# Processing batch 399 (100000 events)
# Processing batch 400 (100000 events)
# Processing batch 401 (100000 events)
# Processing batch 402 (100000 events)
# Processing batch 403 (100000 events)
# Processing batch 404 (100000 events)
# Processing batch 405 (100000 events)
# Processing batch 406 (100000 events)
# Processing batch 407 (100000 events)
# Processing batch 408 (100000 events)
# Processing batch 409 (100000 events)
# Processing batch 410 (100000 events)
# Processing batch 411 (100000 events)
# Processing batch 412 (100000 events)
# Processing batch 413 (100000 events)
# Processing batch 414 (100000 events)
# Processing batch 415 (100000 events)
# Processing batch 416 (100000 events)
# Processing batch 417 (100000 events)
# Processing batch 418 (100000 events)
# Processing batch 419 (100000 events)
# Processing batch 420 (100000 events)
# Processing batch 421 (100000 events)
# Processing batch 422 (100000 events)
# Processing batch 423 (29000 events)
# e-mu events after channel selection: 5271418
# Events after global selection: 4305552
# Events in 0-jet category: 3769
#
# Processing file: Diboson.root (Diboson)
#
# Processing: Diboson.root
# Total events: 11635000
# Processing batch 1 (100000 events)
# Processing batch 2 (100000 events)
# Processing batch 3 (100000 events)
# Processing batch 4 (100000 events)
# Processing batch 5 (100000 events)
# Processing batch 6 (100000 events)
# Processing batch 7 (100000 events)
# Processing batch 8 (100000 events)
# Processing batch 9 (100000 events)
# Processing batch 10 (100000 events)
# Processing batch 11 (100000 events)
# Processing batch 12 (100000 events)
# Processing batch 13 (100000 events)
# Processing batch 14 (100000 events)
# Processing batch 15 (100000 events)
# Processing batch 16 (100000 events)
# Processing batch 17 (100000 events)
# ...
# Processing batch 224 (100000 events)
# Processing batch 225 (100000 events)
# Processing batch 226 (100000 events)
# Processing batch 227 (100000 events)
# Processing batch 228 (100000 events)
# Processing batch 229 (100000 events)
# Processing batch 230 (100000 events)
# Processing batch 231 (100000 events)
# Processing batch 232 (100000 events)
# Processing batch 233 (100000 events)
# Processing batch 234 (100000 events)
# Processing batch 235 (100000 events)
# Processing batch 236 (100000 events)
# Processing batch 237 (100000 events)
# Processing batch 238 (100000 events)
# Processing batch 239 (100000 events)
# Processing batch 240 (100000 events)
# Processing batch 241 (100000 events)
# Processing batch 242 (100000 events)
# Processing batch 243 (100000 events)
# Processing batch 244 (100000 events)
# Processing batch 245 (100000 events)
# Processing batch 246 (100000 events)
# Processing batch 247 (100000 events)
# Processing batch 248 (100000 events)
# Processing batch 249 (100000 events)
# Processing batch 250 (100000 events)
# Processing batch 251 (100000 events)
# Processing batch 252 (100000 events)
# Processing batch 253 (100000 events)
# Processing batch 254 (100000 events)
# Processing batch 255 (100000 events)
# Processing batch 256 (100000 events)
# Processing batch 257 (100000 events)
# Processing batch 258 (100000 events)
# Processing batch 259 (100000 events)
# Processing batch 260 (100000 events)
# Processing batch 261 (100000 events)
# Processing batch 262 (100000 events)
# Processing batch 263 (100000 events)
# Processing batch 264 (100000 events)
# Processing batch 265 (100000 events)
# Processing batch 266 (100000 events)
# Processing batch 267 (100000 events)
# Processing batch 268 (100000 events)
# Processing batch 269 (100000 events)
# Processing batch 270 (100000 events)
# Processing batch 271 (100000 events)
# Processing batch 272 (100000 events)
# Processing batch 273 (100000 events)
# Processing batch 274 (100000 events)
# Processing batch 275 (100000 events)
# Processing batch 276 (100000 events)
# Processing batch 277 (100000 events)
# Processing batch 278 (100000 events)
# Processing batch 279 (100000 events)
# Processing batch 280 (100000 events)
# Processing batch 281 (100000 events)
# Processing batch 282 (100000 events)
# Processing batch 283 (100000 events)
# Processing batch 284 (100000 events)
# Processing batch 285 (100000 events)
# Processing batch 286 (100000 events)
# Processing batch 287 (100000 events)
# Processing batch 288 (100000 events)
# Processing batch 289 (100000 events)
# Processing batch 290 (100000 events)
# Processing batch 291 (100000 events)
# Processing batch 292 (100000 events)
# Processing batch 293 (100000 events)
# Processing batch 294 (100000 events)
# Processing batch 295 (100000 events)
# Processing batch 296 (100000 events)
# Processing batch 297 (100000 events)
# Processing batch 298 (100000 events)
# Processing batch 299 (100000 events)
# Processing batch 300 (100000 events)
# Processing batch 301 (100000 events)
# Processing batch 302 (100000 events)
# Processing batch 303 (100000 events)
# Processing batch 304 (100000 events)
# Processing batch 305 (100000 events)
# Processing batch 306 (100000 events)
# Processing batch 307 (100000 events)
# Processing batch 308 (100000 events)
# Processing batch 309 (100000 events)
# Processing batch 310 (100000 events)
# Processing batch 311 (100000 events)
# Processing batch 312 (100000 events)
# Processing batch 313 (100000 events)
# Processing batch 314 (100000 events)
# Processing batch 315 (100000 events)
# Processing batch 316 (100000 events)
# Processing batch 317 (100000 events)
# Processing batch 318 (100000 events)
# Processing batch 319 (100000 events)
# Processing batch 320 (100000 events)
# Processing batch 321 (100000 events)
# Processing batch 322 (100000 events)
# Processing batch 323 (100000 events)
# Processing batch 324 (100000 events)
# Processing batch 325 (100000 events)
# Processing batch 326 (100000 events)
# Processing batch 327 (100000 events)
# Processing batch 328 (100000 events)
# Processing batch 329 (100000 events)
# Processing batch 330 (100000 events)
# Processing batch 331 (100000 events)
# Processing batch 332 (100000 events)
# Processing batch 333 (100000 events)
# Processing batch 334 (100000 events)
# Processing batch 335 (100000 events)
# Processing batch 336 (100000 events)
# Processing batch 337 (100000 events)
# Processing batch 338 (100000 events)
# Processing batch 339 (100000 events)
# Processing batch 340 (100000 events)
# Processing batch 341 (100000 events)
# Processing batch 342 (100000 events)
# Processing batch 343 (100000 events)
# Processing batch 344 (100000 events)
# Processing batch 345 (100000 events)
# Processing batch 346 (100000 events)
# Processing batch 347 (100000 events)
# Processing batch 348 (100000 events)
# Processing batch 349 (100000 events)
# Processing batch 350 (100000 events)
# Processing batch 351 (100000 events)
# Processing batch 352 (100000 events)
# Processing batch 353 (100000 events)
# Processing batch 354 (100000 events)
# Processing batch 355 (100000 events)
# Processing batch 356 (100000 events)
# Processing batch 357 (100000 events)
# Processing batch 358 (100000 events)
# Processing batch 359 (100000 events)
# Processing batch 360 (100000 events)
# Processing batch 361 (100000 events)
# Processing batch 362 (100000 events)
# Processing batch 363 (100000 events)
# Processing batch 364 (100000 events)
# Processing batch 365 (100000 events)
# Processing batch 366 (100000 events)
# Processing batch 367 (100000 events)
# Processing batch 368 (100000 events)
# Processing batch 369 (100000 events)
# Processing batch 370 (100000 events)
# Processing batch 371 (100000 events)
# Processing batch 372 (100000 events)
# Processing batch 373 (100000 events)
# Processing batch 374 (100000 events)
# Processing batch 375 (100000 events)
# Processing batch 376 (100000 events)
# Processing batch 377 (100000 events)
# Processing batch 378 (100000 events)
# Processing batch 379 (100000 events)
# Processing batch 380 (100000 events)
# Processing batch 381 (100000 events)
# Processing batch 382 (100000 events)
# Processing batch 383 (100000 events)
# Processing batch 384 (100000 events)
# Processing batch 385 (100000 events)
# Processing batch 386 (100000 events)
# Processing batch 387 (100000 events)
# Processing batch 388 (100000 events)
# Processing batch 389 (100000 events)
# Processing batch 390 (100000 events)
# Processing batch 391 (100000 events)
# Processing batch 392 (100000 events)
# Processing batch 393 (100000 events)
# Processing batch 394 (100000 events)
# Processing batch 395 (100000 events)
# Processing batch 396 (100000 events)
# Processing batch 397 (100000 events)
# Processing batch 398 (100000 events)
# Processing batch 399 (100000 events)
# Processing batch 400 (100000 events)
# Processing batch 401 (100000 events)
# Processing batch 402 (100000 events)
# Processing batch 403 (100000 events)
# Processing batch 404 (100000 events)
# Processing batch 405 (100000 events)
# Processing batch 406 (100000 events)
# Processing batch 407 (100000 events)
# Processing batch 408 (100000 events)
# Processing batch 409 (100000 events)
# Processing batch 410 (100000 events)
# Processing batch 411 (100000 events)
# Processing batch 412 (100000 events)
# Processing batch 413 (100000 events)
# Processing batch 414 (100000 events)
# Processing batch 415 (100000 events)
# Processing batch 416 (100000 events)
# Processing batch 417 (100000 events)
# Processing batch 418 (100000 events)
# Processing batch 419 (100000 events)
# Processing batch 420 (100000 events)
# Processing batch 421 (100000 events)
# Processing batch 422 (100000 events)
# Processing batch 423 (100000 events)
# Processing batch 424 (100000 events)
# Processing batch 425 (100000 events)
# Processing batch 426 (100000 events)
# Processing batch 427 (100000 events)
# Processing batch 428 (100000 events)
# Processing batch 429 (100000 events)
# Processing batch 430 (100000 events)
# Processing batch 431 (100000 events)
# Processing batch 432 (100000 events)
# Processing batch 433 (100000 events)
# Processing batch 434 (100000 events)
# Processing batch 435 (100000 events)
# Processing batch 436 (100000 events)
# Processing batch 437 (100000 events)
# Processing batch 438 (100000 events)
# Processing batch 439 (100000 events)
# Processing batch 440 (100000 events)
# Processing batch 441 (100000 events)
# Processing batch 442 (100000 events)
# Processing batch 443 (100000 events)
# Processing batch 444 (100000 events)
# Processing batch 445 (100000 events)
# Processing batch 446 (100000 events)
# Processing batch 447 (100000 events)
# Processing batch 448 (100000 events)
# Processing batch 449 (100000 events)
# Processing batch 450 (100000 events)
# Processing batch 451 (100000 events)
# Processing batch 452 (100000 events)
# Processing batch 453 (100000 events)
# Processing batch 454 (100000 events)
# Processing batch 455 (100000 events)
# Processing batch 456 (100000 events)
# Processing batch 457 (100000 events)
# Processing batch 458 (100000 events)
# Processing batch 459 (100000 events)
# Processing batch 460 (100000 events)
# Processing batch 461 (100000 events)
# Processing batch 462 (100000 events)
# Processing batch 463 (100000 events)
# Processing batch 464 (100000 events)
# Processing batch 465 (100000 events)
# Processing batch 466 (100000 events)
# Processing batch 467 (100000 events)
# Processing batch 468 (100000 events)
# Processing batch 469 (100000 events)
# Processing batch 470 (100000 events)
# Processing batch 471 (100000 events)
# Processing batch 472 (100000 events)
# Processing batch 473 (100000 events)
# Processing batch 474 (100000 events)
# Processing batch 475 (100000 events)
# Processing batch 476 (100000 events)
# Processing batch 477 (100000 events)
# Processing batch 478 (100000 events)
# Processing batch 479 (100000 events)
# Processing batch 480 (100000 events)
# Processing batch 481 (100000 events)
# Processing batch 482 (100000 events)
# Processing batch 483 (100000 events)
# Processing batch 484 (100000 events)
# Processing batch 485 (100000 events)
# Processing batch 486 (100000 events)
# Processing batch 487 (100000 events)
# Processing batch 488 (100000 events)
# Processing batch 489 (100000 events)
# Processing batch 490 (100000 events)
# Processing batch 491 (100000 events)
# Processing batch 492 (100000 events)
# Processing batch 493 (100000 events)
# Processing batch 494 (100000 events)
# Processing batch 495 (100000 events)
# Processing batch 496 (100000 events)
# Processing batch 497 (100000 events)
# Processing batch 498 (100000 events)
# Processing batch 499 (100000 events)
# Processing batch 500 (100000 events)
# Processing batch 501 (100000 events)
# Processing batch 502 (100000 events)
# Processing batch 503 (100000 events)
# Processing batch 504 (100000 events)
# Processing batch 505 (100000 events)
# Processing batch 506 (100000 events)
# Processing batch 507 (100000 events)
# Processing batch 508 (100000 events)
# Processing batch 509 (100000 events)
# Processing batch 510 (100000 events)
# Processing batch 511 (100000 events)
# Processing batch 512 (100000 events)
# Processing batch 513 (100000 events)
# Processing batch 514 (100000 events)
# Processing batch 515 (100000 events)
# Processing batch 516 (100000 events)
# Processing batch 517 (100000 events)
# Processing batch 518 (100000 events)
# Processing batch 519 (100000 events)
# Processing batch 520 (100000 events)
# Processing batch 521 (100000 events)
# Processing batch 522 (100000 events)
# Processing batch 523 (100000 events)
# Processing batch 524 (100000 events)
# Processing batch 525 (100000 events)
# Processing batch 526 (100000 events)
# Processing batch 527 (100000 events)
# Processing batch 528 (100000 events)
# Processing batch 529 (100000 events)
# Processing batch 530 (100000 events)
# Processing batch 531 (100000 events)
# Processing batch 532 (100000 events)
# Processing batch 533 (100000 events)
# Processing batch 534 (100000 events)
# Processing batch 535 (100000 events)
# Processing batch 536 (100000 events)
# Processing batch 537 (100000 events)
# Processing batch 538 (100000 events)
# Processing batch 539 (100000 events)
# Processing batch 540 (100000 events)
# Processing batch 541 (100000 events)
# Processing batch 542 (100000 events)
# Processing batch 543 (100000 events)
# Processing batch 544 (100000 events)
# Processing batch 545 (100000 events)
# Processing batch 546 (100000 events)
# Processing batch 547 (100000 events)
# Processing batch 548 (100000 events)
# Processing batch 549 (100000 events)
# Processing batch 550 (100000 events)
# Processing batch 551 (100000 events)
# Processing batch 552 (100000 events)
# Processing batch 553 (100000 events)
# Processing batch 554 (100000 events)
# Processing batch 555 (100000 events)
# Processing batch 556 (100000 events)
# Processing batch 557 (100000 events)
# Processing batch 558 (100000 events)
# Processing batch 559 (100000 events)
# Processing batch 560 (100000 events)
# Processing batch 561 (100000 events)
# Processing batch 562 (100000 events)
# Processing batch 563 (100000 events)
# Processing batch 564 (100000 events)
# Processing batch 565 (100000 events)
# Processing batch 566 (100000 events)
# Processing batch 567 (100000 events)
# Processing batch 568 (100000 events)
# Processing batch 569 (100000 events)
# Processing batch 570 (100000 events)
# Processing batch 571 (100000 events)
# Processing batch 572 (100000 events)
# Processing batch 573 (100000 events)
# Processing batch 574 (100000 events)
# Processing batch 575 (100000 events)
# Processing batch 576 (100000 events)
# Processing batch 577 (100000 events)
# Processing batch 578 (100000 events)
# Processing batch 579 (100000 events)
# Processing batch 580 (100000 events)
# Processing batch 581 (100000 events)
# Processing batch 582 (100000 events)
# Processing batch 583 (100000 events)
# Processing batch 584 (100000 events)
# Processing batch 585 (100000 events)
# Processing batch 586 (100000 events)
# Processing batch 587 (100000 events)
# Processing batch 588 (100000 events)
# Processing batch 589 (100000 events)
# Processing batch 590 (100000 events)
# Processing batch 591 (100000 events)
# Processing batch 592 (100000 events)
# Processing batch 593 (100000 events)
# Processing batch 594 (100000 events)
# Processing batch 595 (100000 events)
# Processing batch 596 (100000 events)
# Processing batch 597 (100000 events)
# Processing batch 598 (100000 events)
# Processing batch 599 (100000 events)
# Processing batch 600 (100000 events)
# Processing batch 601 (100000 events)
# Processing batch 602 (100000 events)
# Processing batch 603 (100000 events)
# Processing batch 604 (100000 events)
# Processing batch 605 (100000 events)
# Processing batch 606 (100000 events)
# Processing batch 607 (100000 events)
# Processing batch 608 (100000 events)
# Processing batch 609 (100000 events)
# Processing batch 610 (100000 events)
# Processing batch 611 (100000 events)
# Processing batch 612 (100000 events)
# Processing batch 613 (100000 events)
# Processing batch 614 (100000 events)
# Processing batch 615 (100000 events)
# Processing batch 616 (100000 events)
# Processing batch 617 (100000 events)
# Processing batch 618 (100000 events)
# Processing batch 619 (100000 events)
# Processing batch 620 (100000 events)
# Processing batch 621 (100000 events)
# Processing batch 622 (100000 events)
# Processing batch 623 (100000 events)
# Processing batch 624 (100000 events)
# Processing batch 625 (100000 events)
# Processing batch 626 (100000 events)
# Processing batch 627 (100000 events)
# Processing batch 628 (100000 events)
# Processing batch 629 (100000 events)
# Processing batch 630 (100000 events)
# Processing batch 631 (100000 events)
# Processing batch 632 (100000 events)
# Processing batch 633 (100000 events)
# Processing batch 634 (100000 events)
# Processing batch 635 (100000 events)
# Processing batch 636 (100000 events)
# Processing batch 637 (100000 events)
# Processing batch 638 (100000 events)
# Processing batch 639 (100000 events)
# Processing batch 640 (100000 events)
# Processing batch 641 (100000 events)
# Processing batch 642 (100000 events)
# Processing batch 643 (100000 events)
# Processing batch 644 (100000 events)
# Processing batch 645 (100000 events)
# Processing batch 646 (100000 events)
# Processing batch 647 (100000 events)
# Processing batch 648 (100000 events)
# Processing batch 649 (100000 events)
# Processing batch 650 (100000 events)
# Processing batch 651 (100000 events)
# Processing batch 652 (36783 events)
# e-mu events after channel selection: 1108
# Events after global selection: 614
# Events in 0-jet category: 89

# %% [markdown]
# ### Plotting Invariant Mass Distributions
#
# Visualize the invariant mass of $e\mu$ pairs for signal and backgrounds:
#
# 1. **Create a figure and axis** with a size of 10 × 6 inches.
# 2. **Loop over all datasets** (`signal` and backgrounds):
#    - Convert `masses` from awkward arrays to NumPy arrays
#    - Fill a histogram using `Hist` with predefined mass bins
#    - Set line width and transparency: signal is thicker and fully opaque, backgrounds thinner and semi-transparent
#    - Plot histogram as a step plot (`histtype="step"`) with the assigned color
# 3. **Axis labels and title**:
#    - X-axis: $m_{e\mu}$ [GeV]
#    - Y-axis: arbitrary units
#    - Title: "Invariant Mass: Signal vs Backgrounds in $e\mu$ Channel"
# 4. **Legend, grid, and axis limits**:
#    - Legend shows dataset labels
#    - Disable grid
#    - Set X-axis from 0 to 200 GeV
# 5. **Adjust layout** and display the plot.

# %%
# plt.figure(figsize=(10, 6))
fig, ax = plt.subplots(figsize=(10, 6))

for label in files.keys():
    if event_variables[label] is not None:
        masses = event_variables[label]['mass']
        masses_np = ak.to_numpy(masses)
        # hist, _ = np.histogram(masses_np, bins=mass_bins, density=True)
        # bin_centers = (mass_bins[:-1] + mass_bins[1:]) / 2
        
        h = Hist.new.Var(mass_bins, name="masses").Double()        
        h.fill(masses=masses_np)

        linewidth = 2.5 if label == 'signal' else 1.5
        alpha = 1.0 if label == 'signal' else 0.8
        
        # plt.step(bin_centers, hist, where="mid", 
        #          label=label, color=colors[label], 
        #          linewidth=linewidth, alpha=alpha)

        h.plot(ax=ax, histtype="step", label=label, color=colors[label],
               linewidth=linewidth, alpha=alpha,density =True,yerr=False)
        
ax.set_xlabel(r"$m_{e\mu}$ [GeV]", fontsize=12)
ax.set_ylabel("Random units", fontsize=12)
ax.set_title("Invariant Mass: Signal vs Backgrounds in $e\\mu$ Channel", fontsize=14)
ax.legend()
ax.grid(False)
ax.set_xlim(10, 200)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Leading and Subleading Lepton Kinematic Distributions
#
# Create 2 × 3 subplots to visualize the kinematics of leading and subleading leptons:
#
# 1. **Define binning** for transverse momentum ($p_T$), pseudorapidity ($\eta$), and azimuthal angle ($\phi$).
# 2. **Loop over lepton types** (`leading` and `subleading`) and kinematic variables (`pt`, `eta`, `phi`).
# 3. **For each dataset** (signal and backgrounds):
#    - Extract the corresponding lepton collection from `event_variables`
#    - Retrieve the variable of interest
#    - Fill a histogram using `Hist` and convert to NumPy if necessary
#    - Plot as a step plot with dataset-specific color, line width, and transparency
# 4. **Axis formatting**:
#    - Set X-axis labels and limits according to variable type
#    - Y-axis normalized to unity
#    - Light grid lines for readability
#    - Legends with small font to fit in subplots
# 5. **Overall figure title**: "Leading and Subleading Lepton Distributions in $e\mu$ Events"
# 6. **Layout adjustment** and display the figure.

# %%
fig, axes = plt.subplots(2, 3, figsize=(15, 10))

# Define binning
pt_bins = np.linspace(10, 200, 40)
eta_bins = np.linspace(-2.5, 2.5, 40)
phi_bins = np.linspace(-np.pi, np.pi, 40)
bins_dict = {
    'pt': pt_bins,
    'eta': eta_bins,
    'phi': phi_bins
}

# Plot for each kinematic variable
variables = ['pt', 'eta', 'phi']
leptons = ['leading', 'subleading']

for i, lep_type in enumerate(leptons):
    for j, var in enumerate(variables):
        ax = axes[i, j]
       
        # Plot each sample
        for label in files.keys():
            if label in event_variables and event_variables[label] is not None:
                # Get the appropriate lepton collection
                if lep_type == 'leading':
                    lepton_data = event_variables[label]['leading']
                else:  # subleading
                    lepton_data = event_variables[label]['subleading']
               
                # Get the variable data
                data = getattr(lepton_data, var)
               
                if len(data) > 0:
                    data_np = ak.to_numpy(data)
                   
                    # Create histogram using hist library
                    h = Hist.new.Var(bins_dict[var], name=var).Double()
                    h.fill(**{var: data_np})
                   
                    # Plot
                    linewidth = 2.5 if label == 'signal' else 1.5
                    alpha = 1.0 if label == 'signal' else 0.7
                    h.plot(ax=ax, histtype="step", label=label, color=colors[label],
                           linewidth=linewidth, alpha=alpha, density=True,yerr=False)
       
        # Formatting
        if var == 'pt':
            ax.set_xlabel(f'{lep_type.capitalize()} lepton $p_T$ [GeV]')
            ax.set_xlim(10, 200)
        elif var == 'eta':
            ax.set_xlabel(f'{lep_type.capitalize()} lepton $\\eta$')
            ax.set_xlim(-2.5, 2.5)
        else:
            ax.set_xlabel(f'{lep_type.capitalize()} lepton $\\phi$')
            ax.set_xlim(-np.pi, np.pi)
           
        ax.set_ylabel('Random units')
        ax.grid(True, alpha=0.3)
        ax.legend(fontsize=8)

plt.suptitle('Leading and Subleading Lepton Distributions in $e\\mu$ Events', fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Event-Level Kinematic Distributions
#
# Visualize key event-level variables for $e\mu$ events in a 2 × 2 grid:
#
# 1. **Define variables**:
#    - Missing transverse energy ($E_T^{miss}$)
#    - Azimuthal angle difference between leptons ($\Delta\phi_{e\mu}$)
#    - Transverse momentum of the dilepton system ($p_T^{e\mu}$)
#    - Invariant mass of the dilepton system ($m_{e\mu}$)
#
# 2. **Loop over variables and datasets**:
#    - Extract the variable data from `event_variables`
#    - Fill a histogram using `Hist` and convert awkward arrays to NumPy
#    - Plot as a step histogram with dataset-specific color, line width, and transparency
#
# 3. **Axis formatting**:
#    - X-axis label and limits defined per variable
#    - Y-axis normalized to unity
#    - Light grid lines for readability
#    - Legend included with small font
#
# 4. **Figure title**: "Event-Level Distributions in $e\mu$ Channel"
# 5. **Layout adjustment** and display the figure.

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 10))
axes = axes.flatten()

event_vars = {
    'met': {
        'bins': np.linspace(20, 200, 30),
        'xlabel': '$E_T^{miss}$ [GeV]',
        'xlim': (20, 200)
    },
    'dphi': {
        'bins': np.linspace(0, np.pi, 30),
        'xlabel': '$\\Delta\\phi_{e\\mu}$ [rad]',
        'xlim': (0, np.pi)
    },
    'ptll': {
        'bins': np.linspace(30, 200, 30),
        'xlabel': '$p_T^{e\\mu}$ [GeV]',
        'xlim': (30, 200)
    },
    'mass': {
        'bins': np.linspace(10, 200, 30),
        'xlabel': '$m_{e\\mu}$ [GeV]',
        'xlim': (10, 200)
    }
}

for idx, (var_name, var_props) in enumerate(event_vars.items()):
    ax = axes[idx]
   
    for sample in files.keys():
        if event_variables[sample] is not None and var_name in event_variables[sample]:
            data = event_variables[sample][var_name]
            data_np = ak.to_numpy(data)
           
            if len(data_np) > 0:
                # Create histogram using hist library
                h = Hist.new.Var(var_props['bins'], name=var_name).Double()
                h.fill(**{var_name: data_np})
               
                # Plot
                linewidth = 2.5 if sample == 'signal' else 1.5
                alpha = 1.0 if sample == 'signal' else 0.7
                h.plot(ax=ax, histtype="step", label=sample, color=colors[sample],
                       linewidth=linewidth, alpha=alpha, density=True, yerr=False)
   
    ax.set_xlabel(var_props['xlabel'], fontsize=12)
    ax.set_ylabel('Normalized to unity', fontsize=12)
    ax.set_xlim(var_props['xlim'])
    ax.grid(True, alpha=0.3)
    ax.legend(fontsize=8)

plt.suptitle('Event-Level Distributions in $e\\mu$ Channel', fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Transverse mass of higgs and transverse mass of subleading lepton & MET

# %%
# Define bins 
mth_bins = np.linspace(60, 200, 31)  
mt_l2_bins = np.linspace(30, 200, 31)  

# subplots side by side
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 6))

#  Higgs Transverse Mass (mT^H)
for sample in files.keys():  
    if sample in event_variables and event_variables[sample] is not None and 'mt_higgs' in event_variables[sample]:
        mt_higgs = event_variables[sample]['mt_higgs']
        if len(mt_higgs) > 0:  
            mt_higgs_np = ak.to_numpy(mt_higgs)
            
            h = Hist.new.Var(mth_bins, name="mt_higgs").Double()        
            h.fill(**{'mt_higgs': mt_higgs_np})  

            linewidth = 2.5 if sample == 'signal' else 1.5
            alpha = 1.0 if sample == 'signal' else 0.8
            
            h.plot(ax=ax1, histtype="step", label=sample, color=colors[sample],
                   linewidth=linewidth, alpha=alpha, density=True, yerr=False)

        
ax1.set_xlabel(r"$m_T^H$ [GeV]", fontsize=12)
ax1.set_ylabel("Random units", fontsize=12)  
ax1.set_title(r"Higgs Transverse Mass", fontsize=14)
ax1.legend()
ax1.grid(True, alpha=0.3)  
ax1.set_xlim(60, 200)

#  mT between subleading lepton and MET
for sample in files.keys():  
    if sample in event_variables and event_variables[sample] is not None and 'mt_l2_met' in event_variables[sample]:
        mt_l2_met = event_variables[sample]['mt_l2_met']
        if len(mt_l2_met) > 0:  
            mt_l2_met_np = ak.to_numpy(mt_l2_met)
            
            h = Hist.new.Var(mt_l2_bins, name="mt_l2_met").Double()        
            h.fill(**{'mt_l2_met': mt_l2_met_np})  

            linewidth = 2.5 if sample == 'signal' else 1.5
            alpha = 1.0 if sample == 'signal' else 0.8
            
            h.plot(ax=ax2, histtype="step", label=sample, color=colors[sample],
                   linewidth=linewidth, alpha=alpha, density=True, yerr=False)

        
ax2.set_xlabel(r"$m_T(\ell_2, E_T^{miss})$ [GeV]", fontsize=12)
ax2.set_ylabel("Random units", fontsize=12)  
ax2.set_title(r"$m_T$(Subleading Lepton, MET)", fontsize=14)
ax2.legend()
ax2.grid(True, alpha=0.3)  
ax2.set_xlim(30, 200)

# Add  title
fig.suptitle("Transverse Mass Distributions: Signal vs Backgrounds in 0-jet Category", fontsize=16, y=1.02)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Summary Statistics of Selected Events
#
# After applying the $e\mu$ selection, we can quickly summarize each dataset with a few key statistics:
#
# - **Number of events:** total events that survive the selection
# - **Mean invariant mass ($m_{e\mu}$):** average mass of the eμ system
# - **Mean missing transverse energy (MET):** average MET from neutrinos
# - **Mean azimuthal separation ($\Delta\phi_{\ell\ell}$):** average angular separation between the electron and muon
# - **Mean dilepton transverse momentum ($p_T^{\ell\ell}$):** average transverse momentum of the eμ system
#
# These statistics provide a **quick sanity check** and make it easy to compare the **signal** and **background** distributions at a glance, helping us spot any unexpected behavior before moving on to deeper analysis.

# %%
# print("\n=== Summary Statistics ===\n")
# for label in files.keys():
#     if event_variables[label] is not None:
#         print(f"{label}:")
#         print(f"  Number of events: {len(event_variables[label]['mass'])}")
#         print(f"  Mean mass: {np.mean(ak.to_numpy(event_variables[label]['mass'])):.2f} GeV")
#         print(f"  Mean MET: {np.mean(ak.to_numpy(event_variables[label]['met'])):.2f} GeV")
#         print(f"  Mean dphi: {np.mean(ak.to_numpy(event_variables[label]['dphi'])):.3f} rad")
#         print(f"  Mean ptll: {np.mean(ak.to_numpy(event_variables[label]['ptll'])):.2f} GeV")
#         print()

# %% [markdown]
# ### Stacked Histogram for Event-Level Variables
#
# This function creates a stacked histogram combining all datasets:
#
# 1. **Order of stacking**:
#    - Backgrounds first: Drell–Yan, Top–antitop, Diboson, Single Top, W+jets
#    - Signal on top
#
# 2. **Collect data** for each sample from `var_data` for the specified `variable_name`.
#    - Convert awkward arrays to NumPy
#    - Skip empty datasets with warnings
#
# 3. **Plot stacked histogram**:
#    - Use dataset-specific colors
#    - Semi-transparent (`alpha=0.8`) with black edges
#    - X-axis: variable name (from `var_props['xlabel']`)
#    - Y-axis: number of events, log scale enabled with minimum 0.1 to avoid log(0)
#
# 4. **Add legend, title, and formatting**:
#    - Legend in upper right
#    - Grid disabled for clarity
#    - Layout adjusted with `tight_layout`
#
# This provides a clear visualization of signal and background contributions to a given event-level variable.

# %%
def create_stacked_plot(variable_name, var_data, var_props, colors):
    """Create stacked histogram with all samples stacked together"""
   
    fig, ax = plt.subplots(figsize=(10, 6))
   
    # Define the order of stacking: backgrounds first, then signal on top
    backgrounds = ['DY to Tau_Tau', 'Top antitop', 'Diboson', 'Single Top', 'Wjets']
    signal = ['signal']

# Combine all samples in the order we want them stacked
    all_samples = backgrounds + signal  
   
    # Collect data for all samples
    all_data = []
    all_labels = []
    all_colors = []
   
    for sample in all_samples:
        if sample in var_data and var_data[sample] is not None:
            if variable_name in var_data[sample]:
                data = ak.to_numpy(var_data[sample][variable_name])
                if len(data) > 0:
                    all_data.append(data)
                    all_labels.append(sample)
                    all_colors.append(colors[sample])

   
    # Create the stacked histogram
    if all_data:
        n, bins, patches = ax.hist(all_data, bins=var_props['bins'],
                                   label=all_labels, color=all_colors,
                                   stacked=True, alpha=0.8, 
                                    linewidth=0.5)

   
    ax.set_xlabel(var_props['xlabel'], fontsize=12)
    ax.set_ylabel('Events', fontsize=12)
    ax.set_xlim(var_props['xlim'])
    ax.legend(loc='upper right', fontsize=10)
    ax.grid(False)
   
    plt.title(f'Stacked {variable_name.capitalize()} Distribution', fontsize=14)
    
    
    if all(len(d) > 0 for d in all_data):
        plt.yscale('log')
        ax.set_ylim(bottom=0.1)
    
    plt.tight_layout()
    plt.show()

# %%
# Create stacked plots for all event variables
for var_name, var_props in event_vars.items():
    create_stacked_plot(var_name, event_variables, var_props, colors)
